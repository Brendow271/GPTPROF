# %%
import subprocess

def compile_with_clang(source_path, include_dirs):
    """
    Компилирует C++ код с использованием clang++, учитывая пути к заголовочным файлам.

    :param source_path: Путь к исходному файлу (.cpp).
    :param include_dirs: Список путей к заголовочным файлам (для флага -I).
    :return: Сообщение о результате компиляции.
    """
    try:
        # Базовая команда для компиляции
        command = ["clang++", source_path, "-o", "output", "-std=c++17", "-Wall"]

        # Добавление путей к заголовочным файлам (-I)
        for include_dir in include_dirs:
            command.append("-I" + include_dir)

        # Выполнение команды
        result = subprocess.run(
            command,
            check=True,  # Вызовет исключение, если команда завершится с ошибкой
            stdout=subprocess.PIPE,
            stderr=subprocess.PIPE,
            text=True  # Вывод в текстовом формате
        )

        # Если компиляция успешна
        return f"Компиляция успешно завершена! Исполняемый файл: output"

    except subprocess.CalledProcessError as e:
        # Если произошла ошибка компиляции
        error_message = e.stderr.strip()
        return f"Ошибка компиляции:\n{error_message}"
    except FileNotFoundError:
        # Если clang++ не установлен или не найден
        return "Ошибка: clang++ не найден. Убедитесь, что он установлен и доступен в PATH."
    
# source_path = "E:/openmw/OpenSceneGraph/src/osg/NodeVisitor.cpp"
# include_dirs = ["E:\\openmw\\OpenSceneGraph\\include"]
# library_dirs = ["E:\\openmw\\OpenSceneGraph\\lib"]
# libraries = ["osg", "osgDB", "osgUtil"]

source_path = "C:/GitHub/OpenSceneGraph/src/osg/NodeVisitor.cpp"
include_dirs = ["C:/GitHub/OpenSceneGraph/include"]

result_message = compile_with_clang(source_path, include_dirs)

print(result_message)
# Out:
# Ошибка компиляции:
# In file included from E:/openmw/OpenSceneGraph/src/osg/NodeVisitor.cpp:13:
# In file included from C:/GitHub/OpenSceneGraph/include\osg/NodeVisitor:17:
# In file included from C:/GitHub/OpenSceneGraph/include\osg/Node:18:
# In file included from C:/GitHub/OpenSceneGraph/include\osg/Object:17:
# In file included from C:/GitHub/OpenSceneGraph/include\osg/Referenced:17:
# C:/GitHub/OpenSceneGraph/include\osg/Export:17:9: fatal error: 'osg/Config' file not found
#    17 | #include<osg/Config>
#       |         ^~~~~~~~~~~~
# 1 error generated.

# %%
import os
import re
import pandas as pd
import sqlite3
import configparser
import shlex
import subprocess
import json
import atexit
import gradio as gr
from langchain_mistralai import ChatMistralAI
from langgraph.graph import StateGraph, START, END
from langchain.tools import tool
from typing import TypedDict, Dict, Any

# Определяем тип состояния
class GraphState(TypedDict):
    input: str
    last_path_vtune: str
    module_names: list
    last_path_csv: str
    last_path_callstack: str
    last_path_db: str
    result: str
    command: str
    args: str
    cleaned_args: str
    top_n: str

# Глобальные переменные
gradio_interface_instance = None

# Чтение API-ключа
check_path = os.path.dirname(os.getcwd())
config_path = os.path.join(check_path, "GPTPROF", "config.ini")
config = configparser.ConfigParser()
config.read(config_path)

try:
    mistral_api_key = config["API_KEYS"]["MISTRAL_API_KEY"]
except KeyError:
    raise ValueError("API key not found in config.ini")

# Инициализация модели
mistral_model = "codestral-latest"
llm = ChatMistralAI(model=mistral_model, temperature=0, api_key=mistral_api_key)

# %%
@tool
def export_vtune_to_csv(vtune_file_path: str) -> Dict[str, Any]:
    """
    Exports data from a .vtune file to a CSV file using Intel VTune.
    Returns a dictionary with the result message and the path to the exported CSV.

    Args:
        vtune_file_path (str): Path to the .vtune file.

    Returns:
        dict: Result message and path to the exported CSV.
    """
    if not vtune_file_path:
        return {"message": "Error: File path is empty", "csv_path": None}

    vtune_file_path = vtune_file_path.strip('"')

    if not vtune_file_path.endswith(".vtune"):
        return {"message": "Error: File must have .vtune extension", "csv_path": None}

    if not os.path.exists(vtune_file_path):
        return {"message": f"Error: File {vtune_file_path} not found", "csv_path": None}

    try:
        file_name = os.path.splitext(os.path.basename(vtune_file_path))[0]
        current_directory = os.getcwd()
        output_csv = os.path.join(current_directory, f"{file_name}.csv")
        command = (
            f'vtune -report hotspots -r {shlex.quote(vtune_file_path)} -format=csv -report-output {output_csv}'
        )

        subprocess.run(command, shell=True, check=True)
        return {"message": f"Data exported to {output_csv}", "csv_path": output_csv}

    except subprocess.CalledProcessError as e:
        return {"message": f"Export failed: {e}", "csv_path": None}

# Адаптер для узла графа
def export_vtune_node(state: GraphState) -> Dict[str, Any]:
    """
    Node that processes VTune export.
    Exports data from a .vtune file to CSV and returns updated state.

    Args:
        state (GraphState): Current state of the graph.

    Returns:
        dict: Updated state with the result of the export.
    """
    # Логируем входное состояние
    logging.info("Export node: Starting VTune export process.")
    vtune_path = state.get("last_path_vtune", "")
    logging.info(f"Export node: Received VTune file path: {vtune_path}")

    # Вызываем инструмент для экспорта
    tool_result = export_vtune_to_csv.invoke({"vtune_file_path": vtune_path})
    logging.info(f"Export node: Tool result - Message: {tool_result['message']}, CSV Path: {tool_result['csv_path']}")

    # Обновляем состояние
    updated_state = {
        **state,
        "input": "",
        "last_path_csv": tool_result["csv_path"],
        "result": tool_result["message"]
    }
    logging.info(f"Export node: Updated state after export: {updated_state}")

    return updated_state

# %%
@tool
def filter_by_module(module_names: list, csv_file_path: str) -> Dict[str, Any]:
    """
    Filters data by specified modules and saves the result in a new CSV file.
    Returns a dictionary with the result message and the path to the filtered CSV.

    Args:
        module_names (list): List of module names to filter by.
        csv_file_path (str): Path to the CSV file for filtering.

    Returns:
        dict: Result message and path to the filtered CSV.
    """
    if not os.path.exists(csv_file_path):
        return {"message": f"Error: File {csv_file_path} not found.", "filtered_csv_path": None}

    try:
        # Чтение CSV-файла
        df = pd.read_csv(csv_file_path, sep="\t")

        # Проверка наличия необходимых столбцов
        required_columns = {"Module", "Source File"}
        if not required_columns.issubset(df.columns):
            return {
                "message": f"Error: Missing required columns in CSV file. Expected {required_columns}, got {set(df.columns)}.",
                "filtered_csv_path": None
            }

        # Фильтрация данных
        filtered_df = df[
            (df["Module"].isin(module_names)) &
            (
                    (df["Source File"].str.endswith(".cpp") | df["Source File"].str.endswith(".hpp")) |
                    (df["Source File"] == "[Unknown]")
            )
            ]

        if filtered_df.empty:
            return {"message": "Error: No data found for the specified modules.", "filtered_csv_path": None}

        # Сохранение отфильтрованных данных
        file_name = os.path.basename(csv_file_path)
        filtered_csv_path = os.path.join(os.path.dirname(csv_file_path), f"filtered_{file_name}")
        filtered_df.to_csv(filtered_csv_path, sep="\t", index=False)

        return {
            "message": f"Data filtered by modules {module_names} and saved to {filtered_csv_path}.",
            "filtered_csv_path": filtered_csv_path
        }

    except Exception as e:
        return {"message": f"Error processing data: {e}", "filtered_csv_path": None}


def filter_by_module_node(state: GraphState) -> Dict[str, Any]:
    module_names = state.get("module_names", [])
    csv_file_path = state.get("last_path_csv", None)

    try:
        # Вызываем инструмент через invoke
        tool_result = filter_by_module.invoke({"module_names": module_names, "csv_file_path": csv_file_path})
    except Exception as e:
        return {
            **state,
            "input": "",
            "result": f"Error: Failed to call filter_by_module. Details: {e}"
        }

    updated_state = {
        **state,
        "input": "",
        "last_path_csv": tool_result["filtered_csv_path"],
        "result": tool_result["message"]
    }

    return updated_state

# %%
@tool
def filter_top_n_rows(top_n: str, last_path_csv: str) -> Dict[str, Any]:
    """
    Фильтрует топ-N строк из последнего экспортированного CSV-файла и сохраняет их в новый файл.

    Args:
        top_n (str): Количество строк для возврата.
        last_path_csv (str): Путь к последнему экспортированному CSV-файлу.

    Returns:
        dict: Результат выполнения (сообщение и путь к новому файлу).
    """
    # Проверка, что last_path_csv существует
    if not last_path_csv or not os.path.exists(last_path_csv):
        return {
            "message": "Ошибка: Нет данных для фильтрации. Сначала экспортируйте данные из .vtune.",
            "top_n_csv_path": None
        }

    try:
        # Преобразуем top_n в целое число
        n = int(top_n)
        if n <= 0:
            return {
                "message": "Ошибка: Параметр top_n должен быть положительным числом.",
                "top_n_csv_path": None
            }

        # Чтение данных из последнего экспортированного CSV-файла
        df = pd.read_csv(last_path_csv, sep="\t")

        # Получение топ-N строк
        top_n_rows = df.head(n)

        # Формирование имени файла с топ-N строками
        file_name = os.path.basename(last_path_csv)  # Имя файла с расширением
        file_name_without_ext = os.path.splitext(file_name)[0]  # Имя файла без расширения
        top_n_csv_path = os.path.join(os.path.dirname(last_path_csv), f"top_{n}_{file_name_without_ext}.csv")

        # Сохранение топ-N строк в новый файл
        top_n_rows.to_csv(top_n_csv_path, sep="\t", index=False)

        return {
            "message": f"Топ-{n} строк сохранены в {top_n_csv_path}.",
            "top_n_csv_path": top_n_csv_path
        }

    except ValueError:
        return {
            "message": "Ошибка: Параметр top_n должен быть целым числом.",
            "top_n_csv_path": None
        }
    except Exception as e:
        return {
            "message": f"Ошибка при обработке данных: {e}",
            "top_n_csv_path": None
        }
    
def filter_top_node(state: GraphState) -> Dict[str, Any]:
    """
    Node adapter for the filter_top_n_rows tool.
    Extracts top_n and last_path_csv from the state, calls the tool,
    and returns the updated state.

    Args:
        state (dict): Current state of the graph.

    Returns:
        dict: Updated state after filtering top-N rows.
    """
    # Извлекаем параметры из состояния
    top_n = state.get("top_n", None)
    last_path_csv = state.get("last_path_csv", None)

    # Проверяем, что last_path_csv существует
    if not last_path_csv or not os.path.exists(last_path_csv):
        return {
            **state,
            "input": "",
            "result": "Ошибка: Нет данных для фильтрации. Сначала экспортируйте данные из .vtune."
        }

    try:
        # Вызываем инструмент
        tool_result = filter_top_n_rows.invoke({"top_n": top_n, "last_path_csv": last_path_csv})

        # Обновляем состояние
        updated_state = {
            **state,
            "input": "",
            "last_path_csv": tool_result["top_n_csv_path"],
            "result": tool_result["message"]
        }
        return updated_state

    except Exception as e:
        return {
            **state,
            "input": "",
            "result": f"Ошибка: Не удалось выполнить filter_top. Подробности: {e}"
        }

# %%
@tool
def save_path_files_to_db(directory: str) -> Dict[str, Any]:
    """
    Searches for all .cpp files in the specified directory and saves their full paths to a database.
    The database name is generated from the last folder of the directory path.

    Args:
        directory (str): Directory to search for files. This is a required field.

    Returns:
        dict: Message indicating the result of the operation and the path to the database.
    """
    # Проверка существования директории
    if not os.path.exists(directory):
        return {
            "message": f"Error: Directory {directory} does not exist.",
            "db_path": None
        }

    # Генерация имени базы данных из последней папки в пути
    db_name = os.path.basename(os.path.normpath(directory)) + ".db"

    # Сохраняем базу данных в текущей рабочей директории
    current_directory = os.getcwd()  # Получаем текущую рабочую директорию
    db_path = os.path.join(current_directory, db_name)

    try:
        # Подключение к базе данных (или создание новой)
        conn = sqlite3.connect(db_path)
        cursor = conn.cursor()

        # Создание таблицы с полем module
        cursor.execute("""
        CREATE TABLE IF NOT EXISTS files (
            id INTEGER PRIMARY KEY AUTOINCREMENT,
            file_name TEXT NOT NULL,
            file_path TEXT NOT NULL,
            namespace TEXT NOT NULL,
            module TEXT NOT NULL
        )
        """)
        conn.commit()

        # Поиск только .cpp файлов
        target_extensions = (".cpp")
        # , ".hpp"
        found_files = []
        for root, dirs, files in os.walk(directory):
            for file in files:
                if file.endswith(target_extensions):
                    file_path = os.path.join(root, file)
                    namespace = os.path.splitext(file)[0]
                    module = os.path.basename(root)
                    found_files.append((file, file_path, namespace, module))

        # Вставка данных в базу данных
        for file_name, file_path, namespace, module in found_files:
            cursor.execute("""
            INSERT INTO files (file_name, file_path, namespace, module) VALUES (?, ?, ?, ?)
            """, (file_name, file_path, namespace, module))
        conn.commit()
        conn.close()

        # Возвращаем результат
        return {
            "message": f"Found {len(found_files)} .cpp files. Data saved to database {db_path}.",
            "db_path": db_path
        }

    except Exception as e:
        return {
            "message": f"Error processing data: {e}",
            "db_path": None
        }

def save_paths_node(state: GraphState) -> Dict[str, Any]:
    """
    Node adapter for the save_path_files_to_db tool.
    Extracts directory from the state (from cleaned_args), calls the tool via invoke,
    and returns the updated state.

    Args:
        state (dict): Current state of the graph.

    Returns:
        dict: Updated state after saving paths to the database.
    """
    # Извлекаем директорию из cleaned_args
    directory = state.get("cleaned_args", None)

    # Проверяем, что директория указана
    if not directory or not os.path.exists(directory):
        return {
            **state,
            "input": "",
            "result": f"Error: Directory {directory} does not exist or is invalid."
        }

    try:
        # Вызов инструмента
        tool_result = save_path_files_to_db.invoke({"directory": directory})

        # Обновляем состояние
        updated_state = {
            **state,
            "input": "",
            "last_path_db": tool_result["db_path"],  # Сохраняем путь к базе данных в новом поле
            "result": tool_result["message"]
        }
        return updated_state

    except Exception as e:
        return {
            **state,
            "input": "",
            "result": f"Error: Failed to execute save_paths. Details: {e}"
        }

# %%
def create_function_structure(row):
    """
    Creates a function structure based on a DataFrame row.

    Args:
        row (pd.Series): A row from the DataFrame.

    Returns:
        dict: A dictionary representing the function structure.
    """
    # Полное имя функции (без изменений)
    full_function_name = row["Function"]

    # Разбиваем строку на части
    parts = full_function_name.split("::", maxsplit=2)
    folder_name = parts[0].lower()
    namespace = parts[1]
    function_name = parts[2]

    # Убираем всё, что в скобках, включая сами скобки
    function_name = re.sub(r"\(.*?\)", "", function_name).strip()

    # Если function_name содержит шаблонные параметры, оставляем только имя функции
    if "<" in function_name:
        function_name = function_name.split("::")[-1]

    source_file = row["Source File"]
    module = row["Module"]

    # Создание структуры
    function_structure = {
        "folder_name": folder_name,
        "full_folder_name": "",
        "namespace": namespace,
        "function_name": function_name,
        "full_function_name": full_function_name,
        "source_file": source_file,
        "module": module,
        "code": ""
    }
    return function_structure


def find_and_set_full_folder_name(function: dict, db_name: str = None) -> None:
    """
    Finds the full path to the source code file in the database and adds it to the function structure.
    If source_file is [Unknown], compares module and namespace from the 'files' table with the function's fields.

    Args:
        function (dict): A dictionary representing the function structure.
        db_name (str, optional): The name of the database created by the save_path_files_to_db tool. 
                                 If not provided, the global variable path_last_db is used.
    """
    folder_name = function["folder_name"]
    source_file = function["source_file"]

    # Логирование входных данных
    logging.info(f"find_and_set_full_folder_name: Processing function with folder_name={folder_name}, source_file={source_file}.")

    # Подключение к базе данных
    try:
        conn = sqlite3.connect(db_name)
        cursor = conn.cursor()
        logging.info(f"find_and_set_full_folder_name: Successfully connected to database {db_name}.")
    except Exception as e:
        logging.error(f"find_and_set_full_folder_name: Failed to connect to database {db_name}. Error: {e}")
        return

    try:
        if source_file == "[Unknown]":
            # Альтернативная логика для случая, когда source_file равно [Unknown]
            logging.info(f"find_and_set_full_folder_name: Source file is [Unknown]. Searching for module={function['folder_name']} and namespace={function['namespace']}.")
            cursor.execute("""
            SELECT file_path, module, namespace FROM files
            WHERE module = ? AND namespace = ?
            """, (function["folder_name"], function["namespace"]))

            result = cursor.fetchone()
            if result:
                file_path, module, namespace = result
                function["full_folder_name"] = file_path
                function["source_file"] = f"{namespace}.cpp"
                logging.info(f"find_and_set_full_folder_name: Found matching record. Updated full_folder_name={file_path}, source_file={namespace}.cpp.")
            else:
                logging.warning(f"find_and_set_full_folder_name: No matching record found for module={function['folder_name']} and namespace={function['namespace']} in database {db_name}.")
        else:
            # Основная логика для всех остальных случаев
            logging.info(f"find_and_set_full_folder_name: Searching for file_name={source_file} and namespace={folder_name}.")
            cursor.execute("""
            SELECT file_path FROM files
            WHERE file_name = ? AND module = ?
            """, (source_file, folder_name))

            result = cursor.fetchone()
            if result:
                function["full_folder_name"] = result[0]
                logging.info(f"find_and_set_full_folder_name: Found file. Updated full_folder_name={result[0]}.")
            else:
                logging.warning(f"find_and_set_full_folder_name: File {source_file} in folder {folder_name} not found in database {db_name}.")

    except Exception as e:
        logging.error(f"find_and_set_full_folder_name: Error occurred while querying the database. Error: {e}")

    finally:
        # Закрываем соединение с базой данных
        conn.close()
        logging.info(f"find_and_set_full_folder_name: Database connection closed.")


def extract_function_details(function):
    """
    Extracts the full code of a function from the source file based on its name.

    Args:
        function (dict): A dictionary representing the function structure.
    """
    # Логирование начала выполнения функции
    logging.info(f"extract_function_details: Processing function with name={function['function_name']}.")

    # Формирование полного пути к файлу
    file_path = function["full_folder_name"]
    logging.info(f"extract_function_details: Full folder name (file path) set to {file_path}.")

    # Чтение содержимого файла
    try:
        with open(file_path, "r", encoding="utf-8") as file:
            content = file.read()
        logging.info(f"extract_function_details: Successfully read file {file_path}.")
    except FileNotFoundError:
        logging.error(f"extract_function_details: File not found: {file_path}.")
        return

    function_name = function["function_name"]

    # Регулярное выражение для поиска функции (начинается с имени функции и заканчивается открывающей фигурной скобкой)
    function_pattern = re.compile(rf"\b{re.escape(function_name)}\b\s*\(.*?\)\s*(?:const)?\s*{{")

    # Поиск функции
    function_match = function_pattern.search(content)
    if not function_match:
        logging.warning(f"extract_function_details: Function {function_name} not found in file {file_path}.")
        return

    # Начальная позиция функции (после сигнатуры)
    start_pos = function_match.start()

    # Счётчик скобок
    brace_count = 1  # Начинаем с 1, так как первая скобка уже найдена
    function_code = function_match.group(0)  # Начинаем с сигнатуры функции
    i = function_match.end()

    # Итерация по символам для поиска конца функции
    logging.info(f"extract_function_details: Searching for the end of the function starting at position {i}.")
    while i < len(content):
        if content[i] == "{":
            brace_count += 1
        elif content[i] == "}":
            brace_count -= 1

        function_code += content[i]

        # Если все скобки закрыты, завершаем чтение
        if brace_count == 0:
            logging.info(f"extract_function_details: End of function found at position {i}.")
            break

        i += 1

    # Заполнение поля code
    function["code"] = function_code
    logging.info(f"extract_function_details: Updated function field: code length={len(function_code)}.")


def save_to_database(functions_list, db_name):
    """
    Saves the data about functions to an SQLite database.
    Args:
        functions_list (list): A list of function structures.
        db_name (str): The name of the database.
    """
    # Подключение к базе данных (или создание новой)
    conn = sqlite3.connect(db_name)
    cursor = conn.cursor()

    # Создание таблицы с учетом обновленной структуры
    cursor.execute("""
    CREATE TABLE IF NOT EXISTS functions (
        id INTEGER PRIMARY KEY AUTOINCREMENT,
        folder_name TEXT NOT NULL,
        full_folder_name TEXT NOT NULL,
        namespace TEXT NOT NULL,
        function_name TEXT NOT NULL,
        full_function_name TEXT NOT NULL,
        source_file TEXT NOT NULL,
        module TEXT NOT NULL,
        code TEXT
    )
    """)
    conn.commit()

    # Вставка данных в таблицу
    for function in functions_list:
        cursor.execute("""
        INSERT INTO functions (
            folder_name, full_folder_name, namespace, function_name, full_function_name,
            source_file, module, code
        ) VALUES (?, ?, ?, ?, ?, ?, ?, ?)
        """, (
            function["folder_name"],
            function["full_folder_name"],
            function["namespace"],
            function["function_name"],
            function["full_function_name"],
            function["source_file"],
            function["module"],
            function["code"]
        ))

    conn.commit()
    conn.close()

@tool
def process_functions_and_save_to_db(input_csv_path: str, db_name: str) -> Dict[str, Any]:
    """
    Processes a CSV file, extracts information about functions, finds source files,
    extracts function code, and saves the data to a database.

    Args:
        input_csv_path (str): Path to the CSV file.
        db_name (str): Name of the database to save the data.

    Returns:
        dict: Message indicating the result of the operation and the path to the database.
    """
    logging.info(f"Process functions tool: Received input_csv_path: {input_csv_path}")
    logging.info(f"Process functions tool: Received db_name: {db_name}")

    # Проверка существования файла CSV
    if not os.path.exists(input_csv_path):
        logging.error(f"Process functions tool: File {input_csv_path} does not exist.")
        return {
            "message": f"Error: File {input_csv_path} does not exist.",
            "db_path": None
        }

    try:
        # Чтение CSV-файла
        logging.info("Process functions tool: Reading CSV file.")
        df = pd.read_csv(input_csv_path, sep="\t")

        # Создание списка структур функций
        logging.info("Process functions tool: Creating function structures.")
        functions_list = []
        for index, row in df.iterrows():
            function_structure = create_function_structure(row)
            functions_list.append(function_structure)
            logging.debug(f"Process functions tool: Created function structure: {function_structure}")

        # Поиск полных путей к исходным файлам
        logging.info("Process functions tool: Finding full paths to source files.")
        for function in functions_list:
            find_and_set_full_folder_name(function, db_name)
            logging.debug(f"Process functions tool: Found full folder name: {function['full_folder_name']}")

        # Извлечение деталей функции
        logging.info("Process functions tool: Extracting function details.")
        for function in functions_list:
            extract_function_details(function)
            logging.debug(f"Process functions tool: Extracted function details: {function}")

        # Сохранение данных в базу данных
        logging.info("Process functions tool: Saving data to database.")
        save_to_database(functions_list, db_name)

        logging.info(f"Process functions tool: Data successfully processed and saved to database {db_name}.")
        return {
            "message": f"Data successfully processed and saved to database {db_name}.",
            "db_path": db_name
        }

    except Exception as e:
        logging.error(f"Process functions tool: Error processing data: {e}")
        return {
            "message": f"Error processing data: {e}",
            "db_path": None
        }

def process_functions_node(state: GraphState) -> Dict[str, Any]:
    """
    Node adapter for the process_functions_and_save_to_db tool.
    Extracts input_csv_path and db_name from the state, calls the tool via invoke,
    and returns the updated state.

    Args:
        state (dict): Current state of the graph.

    Returns:
        dict: Updated state after processing functions and saving to the database.
    """
    logging.info("Process functions node: Entering process_functions_node function.")
    logging.info(f"Process functions node: Received state: {state}")

    # Извлекаем входные данные из состояния
    input_csv_path = state.get("last_path_csv", None)
    db_name = state.get("last_path_db", None)  # Используем новое поле last_path_db

    logging.info(f"Process functions node: Extracted input_csv_path: {input_csv_path}")
    logging.info(f"Process functions node: Extracted db_name: {db_name}")

    # Проверяем, что CSV-файл указан
    if not input_csv_path or not os.path.exists(input_csv_path):
        logging.error(f"Process functions node: CSV file {input_csv_path} does not exist.")
        return {
            **state,
            "input": "",
            "result": f"Error: CSV file {input_csv_path} does not exist."
        }

    # Проверяем, что база данных указана
    if not db_name or not os.path.exists(db_name):
        logging.error(f"Process functions node: Database {db_name} does not exist.")
        return {
            **state,
            "input": "",
            "result": f"Error: Database {db_name} does not exist."
        }

    try:
        logging.info("Process functions node: Invoking process_functions_and_save_to_db tool.")
        tool_result = process_functions_and_save_to_db.invoke({
            "input_csv_path": input_csv_path,
            "db_name": db_name
        })
        logging.info(f"Process functions node: Tool result: {tool_result}")

        # Обновляем состояние
        updated_state = {
            **state,
            "input": "",
            "last_path_db": tool_result["db_path"],  # Обновляем путь к базе данных
            "result": tool_result["message"]
        }
        logging.info(f"Process functions node: Updated state: {updated_state}")
        return updated_state

    except Exception as e:
        logging.error(f"Process functions node: Error executing process_functions_and_save_to_db: {e}")
        return {
            **state,
            "input": "",
            "result": f"Error: Failed to execute process_functions. Details: {e}"
        }

# %%
def print_functions_table(db_name: str) -> None:
    """
    Debugging function to print the entire content of the 'functions' table to the console.

    Args:
        db_name (str): Path to the database file.
    """
    # Проверка существования файла базы данных
    if not db_name or not os.path.exists(db_name):
        print(f"Error: Database file {db_name} not found.")
        return

    try:
        # Подключение к базе данных
        conn = sqlite3.connect(db_name)
        cursor = conn.cursor()

        # Проверка существования таблицы functions
        cursor.execute("SELECT name FROM sqlite_master WHERE type='table' AND name='functions';")
        table_exists = cursor.fetchone()
        if not table_exists:
            print("Error: Table 'functions' does not exist in the database.")
            conn.close()
            return

        # Выборка всех данных из таблицы functions
        cursor.execute("SELECT * FROM functions;")
        rows = cursor.fetchall()

        # Получение заголовков столбцов
        column_names = [description[0] for description in cursor.description]

        # Вывод заголовков
        print("\t".join(column_names))

        # Вывод строк таблицы
        for row in rows:
            print("\t".join(map(str, row)))

        # Закрытие соединения
        conn.close()

    except Exception as e:
        print(f"Error printing 'functions' table: {e}")

print_functions_table("E:\\AAStudy\\0_work\\Work\\Chukanov\\MyWork\\Diplom\\GPTPROF\\openmw.db")
# Out:
# id	folder_name	full_folder_name	namespace	function_name	full_function_name	source_file	module	code
# 1	osg	E:/openmw\OpenSceneGraph\src\osg\Group.cpp	Group	traverse	osg::Group::traverse	Group.cpp	osg.dll	traverse(NodeVisitor& nv)
# {
#     for(NodeList::iterator itr=_children.begin();
#         itr!=_children.end();
#         ++itr)
#     {
#         (*itr)->accept(nv);
#     }
# }
# 2	osg	E:/openmw\OpenSceneGraph\src\osg\State.cpp	State	applyUniformList	osg::State::applyUniformList	State.cpp	osg.dll
# 3	osg	E:/openmw\OpenSceneGraph\src\osg\Group.cpp	Group	computeBound	osg::Group::computeBound	Group.cpp	osg.dll	computeBound() const
# {
#     BoundingSphere bsphere;
#     if (_children.empty())
#     {
#         return bsphere;
#     }
#
#     // note, special handling of the case when a child is an Transform,
#     // such that only Transforms which are relative to their parents coordinates frame (i.e this group)
#     // are handled, Transform relative to and absolute reference frame are ignored.
#
#     BoundingBox bb;
#     bb.init();
#     NodeList::const_iterator itr;
#     for(itr=_children.begin();
#         itr!=_children.end();
#         ++itr)
#     {
#         osg::Node* child = itr->get();
#         const osg::Transform* transform = child->asTransform();
#         if (!transform || transform->getReferenceFrame()==osg::Transform::RELATIVE_RF)
#         {
#             osg::Drawable* drawable = child->asDrawable();
#             if (drawable)
#             {
#                 bb.expandBy(drawable->getBoundingBox());
#             }
#             else
#             {
#                 const osg::BoundingSphere& bs = child->getBound();
#                 bb.expandBy(bs);
#             }
#         }
#     }
#
#     if (!bb.valid())
#     {
#         return bsphere;
#     }
#
#     bsphere._center = bb.center();
#     bsphere._radius = 0.0f;
#     for(itr=_children.begin();
#         itr!=_children.end();
#         ++itr)
#     {
#         osg::Node* child = itr->get();
#         const osg::Transform* transform = child->asTransform();
#         if (!transform || transform->getReferenceFrame()==osg::Transform::RELATIVE_RF)
#         {
#             const BoundingSphere& bs = child->getBound();
#             bsphere.expandRadiusBy(bs);
#         }
#     }
#
#     return bsphere;
# }
# 4	sceneutil		PositionAttitudeTransform	accept	SceneUtil::PositionAttitudeTransform::accept	positionattitudetransform.hpp	openmw.exe
# 5	mwrender	E:/openmw\apps\openmw\mwrender\renderingmanager.cpp	IntersectionVisitorWithIgnoreList	skipTransform	MWRender::IntersectionVisitorWithIgnoreList::skipTransform	renderingmanager.cpp	openmw.exe	skipTransform(osg::Transform& transform)
#         {
#             if (mContainsPagedRefs)
#                 return false;
#
#             osg::UserDataContainer* userDataContainer = transform.getUserDataContainer();
#             if (!userDataContainer)
#                 return false;
#
#             for (unsigned int i = 0; i < userDataContainer->getNumUserObjects(); ++i)
#             {
#                 if (PtrHolder* p = dynamic_cast<PtrHolder*>(userDataContainer->getUserObject(i)))
#                 {
#                     if (std::find(mIgnoreList.begin(), mIgnoreList.end(), p->mPtr) != mIgnoreList.end())
#                     {
#                         return true;
#                     }
#                 }
#             }
#
#             return false;
#         }
# 6	osg	E:/openmw\OpenSceneGraph\src\osg\State.cpp	State	applyAttributeListOnTexUnit	osg::State::applyAttributeListOnTexUnit	State.cpp	osg.dll
# 7	osg	E:/openmw\OpenSceneGraph\src\osg\State.cpp	State	applyAttributeList	osg::State::applyAttributeList	State.cpp	osg.dll
# 8	osg	E:/openmw\OpenSceneGraph\src\osg\Drawable.cpp	Drawable	draw	osg::Drawable::draw	Drawable.cpp	osg.dll	draw(RenderInfo& renderInfo) const
# {
#     State& state = *renderInfo.getState();
#     bool useVertexArrayObject = state.useVertexArrayObject(_useVertexArrayObject);
#     if (useVertexArrayObject)
#     {
#         unsigned int contextID = renderInfo.getContextID();
#
#         VertexArrayState* vas = _vertexArrayStateList[contextID].get();
#         if (!vas)
#         {
#             _vertexArrayStateList[contextID] = vas = createVertexArrayState(renderInfo);
#         }
#         else
#         {
#             // vas->setRequiresSetArrays(getDataVariance()==osg::Object::DYNAMIC);
#         }
#
#         State::SetCurrentVertexArrayStateProxy setVASProxy(state, vas);
#
#         state.bindVertexArrayObject(vas);
#
#         drawInner(renderInfo);
#
#         vas->setRequiresSetArrays(getDataVariance()==osg::Object::DYNAMIC);
#
#         return;
#     }
#
#     // TODO, add check against whether VAO is active and supported
#     if (state.getCurrentVertexArrayState())
#     {
#         //OSG_NOTICE<<"state.getCurrentVertexArrayState()->getVertexArrayObject()="<< state.getCurrentVertexArrayState()->getVertexArrayObject()<<std::endl;
#         state.bindVertexArrayObject(state.getCurrentVertexArrayState());
#     }
#
#
# #ifdef OSG_GL_DISPLAYLISTS_AVAILABLE
#     if (!state.useVertexBufferObject(_supportsVertexBufferObjects && _useVertexBufferObjects) && _useDisplayList)
#     {
#         // get the contextID (user defined ID of 0 upwards) for the
#         // current OpenGL context.
#         unsigned int contextID = renderInfo.getContextID();
#
#         // get the globj for the current contextID.
#         GLuint& globj = _globjList[contextID];
#
#         if( globj == 0 )
#         {
#             // compile the display list
#             globj = generateDisplayList(contextID, getGLObjectSizeHint());
#             glNewList( globj, GL_COMPILE );
#
#             drawInner(renderInfo);
#
#             glEndList();
#         }
#
#         // call the display list
#         glCallList( globj);
#     }
#     else
# #endif
#     {
#         // if state.previousVertexArrayState() is different than currentVertexArrayState bind current
#
#         // OSG_NOTICE<<"Fallback drawInner()........................"<<std::endl;
#
#         drawInner(renderInfo);
#     }
# }
# 9	mwphysics	E:/openmw\apps\openmw\mwphysics\physicssystem.cpp	PhysicsSystem	stepSimulation	MWPhysics::PhysicsSystem::stepSimulation	physicssystem.cpp	openmw.exe	stepSimulation(float dt, bool skipSimulation, osg::Timer_t frameStart, unsigned int frameNumber, osg::Stats& stats)
#     {
#         for (auto& [animatedObject, changed] : mAnimatedObjects)
#         {
#             if (animatedObject->animateCollisionShapes())
#             {
#                 auto obj = mObjects.find(animatedObject->getPtr().mRef);
#                 assert(obj != mObjects.end());
#                 mTaskScheduler->updateSingleAabb(obj->second);
#                 changed = true;
#             }
#             else
#             {
#                 changed = false;
#             }
#         }
#         for (auto& [_, object] : mObjects)
#             object->resetCollisions();
#
# #ifndef BT_NO_PROFILE
#         CProfileManager::Reset();
#         CProfileManager::Increment_Frame_Counter();
# #endif
#
#         mTimeAccum += dt;
#
#         if (skipSimulation)
#             mTaskScheduler->resetSimulation(mActors);
#         else
#         {
#             std::vector<Simulation>& simulations = mSimulations[mSimulationsCounter++ % mSimulations.size()];
#             prepareSimulation(mTimeAccum >= mPhysicsDt, simulations);
#             // modifies mTimeAccum
#             mTaskScheduler->applyQueuedMovements(mTimeAccum, simulations, frameStart, frameNumber, stats);
#         }
#     }
# 10	osg	E:/openmw\OpenSceneGraph\src\osg\State.cpp	State	applyModeListOnTexUnit	osg::State::applyModeListOnTexUnit	State.cpp	osg.dll
# 11	osg	E:/openmw\OpenSceneGraph\src\osg\Group.cpp	Group	traverse	osg::Group::traverse	Group.cpp	osg.dll	traverse(NodeVisitor& nv)
# {
#     for(NodeList::iterator itr=_children.begin();
#         itr!=_children.end();
#         ++itr)
#     {
#         (*itr)->accept(nv);
#     }
# }
# 12	osg	E:/openmw\OpenSceneGraph\src\osg\State.cpp	State	applyUniformList	osg::State::applyUniformList	State.cpp	osg.dll
# 13	osg	E:/openmw\OpenSceneGraph\src\osg\Group.cpp	Group	computeBound	osg::Group::computeBound	Group.cpp	osg.dll	computeBound() const
# {
#     BoundingSphere bsphere;
#     if (_children.empty())
#     {
#         return bsphere;
#     }
#
#     // note, special handling of the case when a child is an Transform,
#     // such that only Transforms which are relative to their parents coordinates frame (i.e this group)
#     // are handled, Transform relative to and absolute reference frame are ignored.
#
#     BoundingBox bb;
#     bb.init();
#     NodeList::const_iterator itr;
#     for(itr=_children.begin();
#         itr!=_children.end();
#         ++itr)
#     {
#         osg::Node* child = itr->get();
#         const osg::Transform* transform = child->asTransform();
#         if (!transform || transform->getReferenceFrame()==osg::Transform::RELATIVE_RF)
#         {
#             osg::Drawable* drawable = child->asDrawable();
#             if (drawable)
#             {
#                 bb.expandBy(drawable->getBoundingBox());
#             }
#             else
#             {
#                 const osg::BoundingSphere& bs = child->getBound();
#                 bb.expandBy(bs);
#             }
#         }
#     }
#
#     if (!bb.valid())
#     {
#         return bsphere;
#     }
#
#     bsphere._center = bb.center();
#     bsphere._radius = 0.0f;
#     for(itr=_children.begin();
#         itr!=_children.end();
#         ++itr)
#     {
#         osg::Node* child = itr->get();
#         const osg::Transform* transform = child->asTransform();
#         if (!transform || transform->getReferenceFrame()==osg::Transform::RELATIVE_RF)
#         {
#             const BoundingSphere& bs = child->getBound();
#             bsphere.expandRadiusBy(bs);
#         }
#     }
#
#     return bsphere;
# }
# 14	sceneutil		PositionAttitudeTransform	accept	SceneUtil::PositionAttitudeTransform::accept	positionattitudetransform.hpp	openmw.exe
# 15	mwrender	E:/openmw\apps\openmw\mwrender\renderingmanager.cpp	IntersectionVisitorWithIgnoreList	skipTransform	MWRender::IntersectionVisitorWithIgnoreList::skipTransform	renderingmanager.cpp	openmw.exe	skipTransform(osg::Transform& transform)
#         {
#             if (mContainsPagedRefs)
#                 return false;
#
#             osg::UserDataContainer* userDataContainer = transform.getUserDataContainer();
#             if (!userDataContainer)
#                 return false;
#
#             for (unsigned int i = 0; i < userDataContainer->getNumUserObjects(); ++i)
#             {
#                 if (PtrHolder* p = dynamic_cast<PtrHolder*>(userDataContainer->getUserObject(i)))
#                 {
#                     if (std::find(mIgnoreList.begin(), mIgnoreList.end(), p->mPtr) != mIgnoreList.end())
#                     {
#                         return true;
#                     }
#                 }
#             }
#
#             return false;
#         }
# 16	osg	E:/openmw\OpenSceneGraph\src\osg\State.cpp	State	applyAttributeListOnTexUnit	osg::State::applyAttributeListOnTexUnit	State.cpp	osg.dll
# 17	osg	E:/openmw\OpenSceneGraph\src\osg\State.cpp	State	applyAttributeList	osg::State::applyAttributeList	State.cpp	osg.dll
# 18	osg	E:/openmw\OpenSceneGraph\src\osg\Drawable.cpp	Drawable	draw	osg::Drawable::draw	Drawable.cpp	osg.dll	draw(RenderInfo& renderInfo) const
# {
#     State& state = *renderInfo.getState();
#     bool useVertexArrayObject = state.useVertexArrayObject(_useVertexArrayObject);
#     if (useVertexArrayObject)
#     {
#         unsigned int contextID = renderInfo.getContextID();
#
#         VertexArrayState* vas = _vertexArrayStateList[contextID].get();
#         if (!vas)
#         {
#             _vertexArrayStateList[contextID] = vas = createVertexArrayState(renderInfo);
#         }
#         else
#         {
#             // vas->setRequiresSetArrays(getDataVariance()==osg::Object::DYNAMIC);
#         }
#
#         State::SetCurrentVertexArrayStateProxy setVASProxy(state, vas);
#
#         state.bindVertexArrayObject(vas);
#
#         drawInner(renderInfo);
#
#         vas->setRequiresSetArrays(getDataVariance()==osg::Object::DYNAMIC);
#
#         return;
#     }
#
#     // TODO, add check against whether VAO is active and supported
#     if (state.getCurrentVertexArrayState())
#     {
#         //OSG_NOTICE<<"state.getCurrentVertexArrayState()->getVertexArrayObject()="<< state.getCurrentVertexArrayState()->getVertexArrayObject()<<std::endl;
#         state.bindVertexArrayObject(state.getCurrentVertexArrayState());
#     }
#
#
# #ifdef OSG_GL_DISPLAYLISTS_AVAILABLE
#     if (!state.useVertexBufferObject(_supportsVertexBufferObjects && _useVertexBufferObjects) && _useDisplayList)
#     {
#         // get the contextID (user defined ID of 0 upwards) for the
#         // current OpenGL context.
#         unsigned int contextID = renderInfo.getContextID();
#
#         // get the globj for the current contextID.
#         GLuint& globj = _globjList[contextID];
#
#         if( globj == 0 )
#         {
#             // compile the display list
#             globj = generateDisplayList(contextID, getGLObjectSizeHint());
#             glNewList( globj, GL_COMPILE );
#
#             drawInner(renderInfo);
#
#             glEndList();
#         }
#
#         // call the display list
#         glCallList( globj);
#     }
#     else
# #endif
#     {
#         // if state.previousVertexArrayState() is different than currentVertexArrayState bind current
#
#         // OSG_NOTICE<<"Fallback drawInner()........................"<<std::endl;
#
#         drawInner(renderInfo);
#     }
# }
# 19	mwphysics	E:/openmw\apps\openmw\mwphysics\physicssystem.cpp	PhysicsSystem	stepSimulation	MWPhysics::PhysicsSystem::stepSimulation	physicssystem.cpp	openmw.exe	stepSimulation(float dt, bool skipSimulation, osg::Timer_t frameStart, unsigned int frameNumber, osg::Stats& stats)
#     {
#         for (auto& [animatedObject, changed] : mAnimatedObjects)
#         {
#             if (animatedObject->animateCollisionShapes())
#             {
#                 auto obj = mObjects.find(animatedObject->getPtr().mRef);
#                 assert(obj != mObjects.end());
#                 mTaskScheduler->updateSingleAabb(obj->second);
#                 changed = true;
#             }
#             else
#             {
#                 changed = false;
#             }
#         }
#         for (auto& [_, object] : mObjects)
#             object->resetCollisions();
#
# #ifndef BT_NO_PROFILE
#         CProfileManager::Reset();
#         CProfileManager::Increment_Frame_Counter();
# #endif
#
#         mTimeAccum += dt;
#
#         if (skipSimulation)
#             mTaskScheduler->resetSimulation(mActors);
#         else
#         {
#             std::vector<Simulation>& simulations = mSimulations[mSimulationsCounter++ % mSimulations.size()];
#             prepareSimulation(mTimeAccum >= mPhysicsDt, simulations);
#             // modifies mTimeAccum
#             mTaskScheduler->applyQueuedMovements(mTimeAccum, simulations, frameStart, frameNumber, stats);
#         }
#     }
# 20	osg	E:/openmw\OpenSceneGraph\src\osg\State.cpp	State	applyModeListOnTexUnit	osg::State::applyModeListOnTexUnit	State.cpp	osg.dll

# %%
import sqlite3

def print_files_table(db_name: str) -> None:
    """
    Debugging function to print the entire content of the 'files' table to the console.

    Args:
        db_name (str): Path to the database file.
    """
    # Проверка существования файла базы данных
    if not db_name or not os.path.exists(db_name):
        print(f"Error: Database file {db_name} not found.")
        return

    try:
        # Подключение к базе данных
        conn = sqlite3.connect(db_name)
        cursor = conn.cursor()

        # Проверка существования таблицы files
        cursor.execute("SELECT name FROM sqlite_master WHERE type='table' AND name='files';")
        table_exists = cursor.fetchone()
        if not table_exists:
            print("Error: Table 'files' does not exist in the database.")
            conn.close()
            return

        # Выборка всех данных из таблицы files
        cursor.execute("SELECT * FROM files;")
        rows = cursor.fetchall()

        # Получение заголовков столбцов
        column_names = [description[0] for description in cursor.description]

        # Вывод заголовков
        print("\t".join(column_names))

        # Вывод строк таблицы
        for row in rows:
            print("\t".join(map(str, row)))

        # Закрытие соединения
        conn.close()

    except Exception as e:
        print(f"Error printing 'files' table: {e}")

print_files_table("E:\\AAStudy\\0_work\\Work\\Chukanov\\MyWork\\Diplom\\GPTPROF\\openmw.db")
# Out:
# id	file_name	file_path	namespace	module
# 1	navmeshtilescache.cpp	E:/openmw\apps\benchmarks\detournavigator\navmeshtilescache.cpp	navmeshtilescache	detournavigator
# 2	benchrefid.cpp	E:/openmw\apps\benchmarks\esm\benchrefid.cpp	benchrefid	esm
# 3	access.cpp	E:/openmw\apps\benchmarks\settings\access.cpp	access	settings
# 4	bsatool.cpp	E:/openmw\apps\bsatool\bsatool.cpp	bsatool	bsatool
# 5	main.cpp	E:/openmw\apps\bulletobjecttool\main.cpp	main	bulletobjecttool
# 6	main.cpp	E:/openmw\apps\components_tests\main.cpp	main	components_tests
# 7	asyncnavmeshupdater.cpp	E:/openmw\apps\components_tests\detournavigator\asyncnavmeshupdater.cpp	asyncnavmeshupdater	detournavigator
# 8	gettilespositions.cpp	E:/openmw\apps\components_tests\detournavigator\gettilespositions.cpp	gettilespositions	detournavigator
# 9	navigator.cpp	E:/openmw\apps\components_tests\detournavigator\navigator.cpp	navigator	detournavigator
# 10	navmeshdb.cpp	E:/openmw\apps\components_tests\detournavigator\navmeshdb.cpp	navmeshdb	detournavigator
# 11	navmeshtilescache.cpp	E:/openmw\apps\components_tests\detournavigator\navmeshtilescache.cpp	navmeshtilescache	detournavigator
# 12	recastmeshbuilder.cpp	E:/openmw\apps\components_tests\detournavigator\recastmeshbuilder.cpp	recastmeshbuilder	detournavigator
# 13	recastmeshobject.cpp	E:/openmw\apps\components_tests\detournavigator\recastmeshobject.cpp	recastmeshobject	detournavigator
# 14	settingsutils.cpp	E:/openmw\apps\components_tests\detournavigator\settingsutils.cpp	settingsutils	detournavigator
# 15	tilecachedrecastmeshmanager.cpp	E:/openmw\apps\components_tests\detournavigator\tilecachedrecastmeshmanager.cpp	tilecachedrecastmeshmanager	detournavigator
# 16	testrefid.cpp	E:/openmw\apps\components_tests\esm\testrefid.cpp	testrefid	esm
# 17	test_fixed_string.cpp	E:/openmw\apps\components_tests\esm\test_fixed_string.cpp	test_fixed_string	esm
# 18	variant.cpp	E:/openmw\apps\components_tests\esm\variant.cpp	variant	esm
# 19	readerscache.cpp	E:/openmw\apps\components_tests\esm3\readerscache.cpp	readerscache	esm3
# 20	testcstringids.cpp	E:/openmw\apps\components_tests\esm3\testcstringids.cpp	testcstringids	esm3
# 21	testesmwriter.cpp	E:/openmw\apps\components_tests\esm3\testesmwriter.cpp	testesmwriter	esm3
# 22	testinfoorder.cpp	E:/openmw\apps\components_tests\esm3\testinfoorder.cpp	testinfoorder	esm3
# 23	testsaveload.cpp	E:/openmw\apps\components_tests\esm3\testsaveload.cpp	testsaveload	esm3
# 24	includes.cpp	E:/openmw\apps\components_tests\esm4\includes.cpp	includes	esm4
# 25	esmdata.cpp	E:/openmw\apps\components_tests\esmloader\esmdata.cpp	esmdata	esmloader
# 26	load.cpp	E:/openmw\apps\components_tests\esmloader\load.cpp	load	esmloader
# 27	record.cpp	E:/openmw\apps\components_tests\esmloader\record.cpp	record	esmloader
# 28	testgridsampling.cpp	E:/openmw\apps\components_tests\esmterrain\testgridsampling.cpp	testgridsampling	esmterrain
# 29	conversion_tests.cpp	E:/openmw\apps\components_tests\files\conversion_tests.cpp	conversion_tests	files
# 30	hash.cpp	E:/openmw\apps\components_tests\files\hash.cpp	hash	files
# 31	lexer.cpp	E:/openmw\apps\components_tests\fx\lexer.cpp	lexer	fx
# 32	technique.cpp	E:/openmw\apps\components_tests\fx\technique.cpp	technique	fx
# 33	test_async.cpp	E:/openmw\apps\components_tests\lua\test_async.cpp	test_async	lua
# 34	test_configuration.cpp	E:/openmw\apps\components_tests\lua\test_configuration.cpp	test_configuration	lua
# 35	test_inputactions.cpp	E:/openmw\apps\components_tests\lua\test_inputactions.cpp	test_inputactions	lua
# 36	test_l10n.cpp	E:/openmw\apps\components_tests\lua\test_l10n.cpp	test_l10n	lua
# 37	test_lua.cpp	E:/openmw\apps\components_tests\lua\test_lua.cpp	test_lua	lua
# 38	test_scriptscontainer.cpp	E:/openmw\apps\components_tests\lua\test_scriptscontainer.cpp	test_scriptscontainer	lua
# 39	test_serialization.cpp	E:/openmw\apps\components_tests\lua\test_serialization.cpp	test_serialization	lua
# 40	test_storage.cpp	E:/openmw\apps\components_tests\lua\test_storage.cpp	test_storage	lua
# 41	test_ui_content.cpp	E:/openmw\apps\components_tests\lua\test_ui_content.cpp	test_ui_content	lua
# 42	test_utilpackage.cpp	E:/openmw\apps\components_tests\lua\test_utilpackage.cpp	test_utilpackage	lua
# 43	test_yaml.cpp	E:/openmw\apps\components_tests\lua\test_yaml.cpp	test_yaml	lua
# 44	compression.cpp	E:/openmw\apps\components_tests\misc\compression.cpp	compression	misc
# 45	progressreporter.cpp	E:/openmw\apps\components_tests\misc\progressreporter.cpp	progressreporter	misc
# 46	testmathutil.cpp	E:/openmw\apps\components_tests\misc\testmathutil.cpp	testmathutil	misc
# 47	test_endianness.cpp	E:/openmw\apps\components_tests\misc\test_endianness.cpp	test_endianness	misc
# 48	test_resourcehelpers.cpp	E:/openmw\apps\components_tests\misc\test_resourcehelpers.cpp	test_resourcehelpers	misc
# 49	test_stringops.cpp	E:/openmw\apps\components_tests\misc\test_stringops.cpp	test_stringops	misc
# 50	testbulletnifloader.cpp	E:/openmw\apps\components_tests\nifloader\testbulletnifloader.cpp	testbulletnifloader	nifloader
# 51	testnifloader.cpp	E:/openmw\apps\components_tests\nifosg\testnifloader.cpp	testnifloader	nifosg
# 52	testobjectcache.cpp	E:/openmw\apps\components_tests\resource\testobjectcache.cpp	testobjectcache	resource
# 53	osgacontroller.cpp	E:/openmw\apps\components_tests\sceneutil\osgacontroller.cpp	osgacontroller	sceneutil
# 54	binaryreader.cpp	E:/openmw\apps\components_tests\serialization\binaryreader.cpp	binaryreader	serialization
# 55	binarywriter.cpp	E:/openmw\apps\components_tests\serialization\binarywriter.cpp	binarywriter	serialization
# 56	integration.cpp	E:/openmw\apps\components_tests\serialization\integration.cpp	integration	serialization
# 57	sizeaccumulator.cpp	E:/openmw\apps\components_tests\serialization\sizeaccumulator.cpp	sizeaccumulator	serialization
# 58	parser.cpp	E:/openmw\apps\components_tests\settings\parser.cpp	parser	settings
# 59	shadermanager.cpp	E:/openmw\apps\components_tests\settings\shadermanager.cpp	shadermanager	settings
# 60	testvalues.cpp	E:/openmw\apps\components_tests\settings\testvalues.cpp	testvalues	settings
# 61	parsedefines.cpp	E:/openmw\apps\components_tests\shader\parsedefines.cpp	parsedefines	shader
# 62	parsefors.cpp	E:/openmw\apps\components_tests\shader\parsefors.cpp	parsefors	shader
# 63	parselinks.cpp	E:/openmw\apps\components_tests\shader\parselinks.cpp	parselinks	shader
# 64	shadermanager.cpp	E:/openmw\apps\components_tests\shader\shadermanager.cpp	shadermanager	shader
# 65	db.cpp	E:/openmw\apps\components_tests\sqlite3\db.cpp	db	sqlite3
# 66	request.cpp	E:/openmw\apps\components_tests\sqlite3\request.cpp	request	sqlite3
# 67	statement.cpp	E:/openmw\apps\components_tests\sqlite3\statement.cpp	statement	sqlite3
# 68	transaction.cpp	E:/openmw\apps\components_tests\sqlite3\transaction.cpp	transaction	sqlite3
# 69	toutf8.cpp	E:/openmw\apps\components_tests\toutf8\toutf8.cpp	toutf8	toutf8
# 70	testpathutil.cpp	E:/openmw\apps\components_tests\vfs\testpathutil.cpp	testpathutil	vfs
# 71	esmtool.cpp	E:/openmw\apps\esmtool\esmtool.cpp	esmtool	esmtool
# 72	labels.cpp	E:/openmw\apps\esmtool\labels.cpp	labels	esmtool
# 73	record.cpp	E:/openmw\apps\esmtool\record.cpp	record	esmtool
# 74	tes4.cpp	E:/openmw\apps\esmtool\tes4.cpp	tes4	esmtool
# 75	convertacdt.cpp	E:/openmw\apps\essimporter\convertacdt.cpp	convertacdt	essimporter
# 76	convertcntc.cpp	E:/openmw\apps\essimporter\convertcntc.cpp	convertcntc	essimporter
# 77	convertcrec.cpp	E:/openmw\apps\essimporter\convertcrec.cpp	convertcrec	essimporter
# 78	converter.cpp	E:/openmw\apps\essimporter\converter.cpp	converter	essimporter
# 79	convertinventory.cpp	E:/openmw\apps\essimporter\convertinventory.cpp	convertinventory	essimporter
# 80	convertnpcc.cpp	E:/openmw\apps\essimporter\convertnpcc.cpp	convertnpcc	essimporter
# 81	convertplayer.cpp	E:/openmw\apps\essimporter\convertplayer.cpp	convertplayer	essimporter
# 82	convertscpt.cpp	E:/openmw\apps\essimporter\convertscpt.cpp	convertscpt	essimporter
# 83	convertscri.cpp	E:/openmw\apps\essimporter\convertscri.cpp	convertscri	essimporter
# 84	importcellref.cpp	E:/openmw\apps\essimporter\importcellref.cpp	importcellref	essimporter
# 85	importcntc.cpp	E:/openmw\apps\essimporter\importcntc.cpp	importcntc	essimporter
# 86	importcrec.cpp	E:/openmw\apps\essimporter\importcrec.cpp	importcrec	essimporter
# 87	importdial.cpp	E:/openmw\apps\essimporter\importdial.cpp	importdial	essimporter
# 88	importer.cpp	E:/openmw\apps\essimporter\importer.cpp	importer	essimporter
# 89	importercontext.cpp	E:/openmw\apps\essimporter\importercontext.cpp	importercontext	essimporter
# 90	importgame.cpp	E:/openmw\apps\essimporter\importgame.cpp	importgame	essimporter
# 91	importinfo.cpp	E:/openmw\apps\essimporter\importinfo.cpp	importinfo	essimporter
# 92	importinventory.cpp	E:/openmw\apps\essimporter\importinventory.cpp	importinventory	essimporter
# 93	importjour.cpp	E:/openmw\apps\essimporter\importjour.cpp	importjour	essimporter
# 94	importklst.cpp	E:/openmw\apps\essimporter\importklst.cpp	importklst	essimporter
# 95	importnpcc.cpp	E:/openmw\apps\essimporter\importnpcc.cpp	importnpcc	essimporter
# 96	importplayer.cpp	E:/openmw\apps\essimporter\importplayer.cpp	importplayer	essimporter
# 97	importproj.cpp	E:/openmw\apps\essimporter\importproj.cpp	importproj	essimporter
# 98	importques.cpp	E:/openmw\apps\essimporter\importques.cpp	importques	essimporter
# 99	importscpt.cpp	E:/openmw\apps\essimporter\importscpt.cpp	importscpt	essimporter
# 100	importscri.cpp	E:/openmw\apps\essimporter\importscri.cpp	importscri	essimporter
# 101	importsplm.cpp	E:/openmw\apps\essimporter\importsplm.cpp	importsplm	essimporter
# 102	main.cpp	E:/openmw\apps\essimporter\main.cpp	main	essimporter
# 103	datafilespage.cpp	E:/openmw\apps\launcher\datafilespage.cpp	datafilespage	launcher
# 104	graphicspage.cpp	E:/openmw\apps\launcher\graphicspage.cpp	graphicspage	launcher
# 105	importpage.cpp	E:/openmw\apps\launcher\importpage.cpp	importpage	launcher
# 106	main.cpp	E:/openmw\apps\launcher\main.cpp	main	launcher
# 107	maindialog.cpp	E:/openmw\apps\launcher\maindialog.cpp	maindialog	launcher
# 108	sdlinit.cpp	E:/openmw\apps\launcher\sdlinit.cpp	sdlinit	launcher
# 109	settingspage.cpp	E:/openmw\apps\launcher\settingspage.cpp	settingspage	launcher
# 110	textslotmsgbox.cpp	E:/openmw\apps\launcher\textslotmsgbox.cpp	textslotmsgbox	launcher
# 111	cellnameloader.cpp	E:/openmw\apps\launcher\utils\cellnameloader.cpp	cellnameloader	utils
# 112	lineedit.cpp	E:/openmw\apps\launcher\utils\lineedit.cpp	lineedit	utils
# 113	openalutil.cpp	E:/openmw\apps\launcher\utils\openalutil.cpp	openalutil	utils
# 114	profilescombobox.cpp	E:/openmw\apps\launcher\utils\profilescombobox.cpp	profilescombobox	utils
# 115	textinputdialog.cpp	E:/openmw\apps\launcher\utils\textinputdialog.cpp	textinputdialog	utils
# 116	importer.cpp	E:/openmw\apps\mwiniimporter\importer.cpp	importer	mwiniimporter
# 117	main.cpp	E:/openmw\apps\mwiniimporter\main.cpp	main	mwiniimporter
# 118	main.cpp	E:/openmw\apps\navmeshtool\main.cpp	main	navmeshtool
# 119	navmesh.cpp	E:/openmw\apps\navmeshtool\navmesh.cpp	navmesh	navmeshtool
# 120	worldspacedata.cpp	E:/openmw\apps\navmeshtool\worldspacedata.cpp	worldspacedata	navmeshtool
# 121	niftest.cpp	E:/openmw\apps\niftest\niftest.cpp	niftest	niftest
# 122	editor.cpp	E:/openmw\apps\opencs\editor.cpp	editor	opencs
# 123	main.cpp	E:/openmw\apps\opencs\main.cpp	main	opencs
# 124	document.cpp	E:/openmw\apps\opencs\model\doc\document.cpp	document	doc
# 125	documentmanager.cpp	E:/openmw\apps\opencs\model\doc\documentmanager.cpp	documentmanager	doc
# 126	loader.cpp	E:/openmw\apps\opencs\model\doc\loader.cpp	loader	doc
# 127	messages.cpp	E:/openmw\apps\opencs\model\doc\messages.cpp	messages	doc
# 128	operation.cpp	E:/openmw\apps\opencs\model\doc\operation.cpp	operation	doc
# 129	operationholder.cpp	E:/openmw\apps\opencs\model\doc\operationholder.cpp	operationholder	doc
# 130	runner.cpp	E:/openmw\apps\opencs\model\doc\runner.cpp	runner	doc
# 131	saving.cpp	E:/openmw\apps\opencs\model\doc\saving.cpp	saving	doc
# 132	savingstages.cpp	E:/openmw\apps\opencs\model\doc\savingstages.cpp	savingstages	doc
# 133	savingstate.cpp	E:/openmw\apps\opencs\model\doc\savingstate.cpp	savingstate	doc
# 134	andnode.cpp	E:/openmw\apps\opencs\model\filter\andnode.cpp	andnode	filter
# 135	booleannode.cpp	E:/openmw\apps\opencs\model\filter\booleannode.cpp	booleannode	filter
# 136	leafnode.cpp	E:/openmw\apps\opencs\model\filter\leafnode.cpp	leafnode	filter
# 137	narynode.cpp	E:/openmw\apps\opencs\model\filter\narynode.cpp	narynode	filter
# 138	notnode.cpp	E:/openmw\apps\opencs\model\filter\notnode.cpp	notnode	filter
# 139	ornode.cpp	E:/openmw\apps\opencs\model\filter\ornode.cpp	ornode	filter
# 140	parser.cpp	E:/openmw\apps\opencs\model\filter\parser.cpp	parser	filter
# 141	textnode.cpp	E:/openmw\apps\opencs\model\filter\textnode.cpp	textnode	filter
# 142	unarynode.cpp	E:/openmw\apps\opencs\model\filter\unarynode.cpp	unarynode	filter
# 143	valuenode.cpp	E:/openmw\apps\opencs\model\filter\valuenode.cpp	valuenode	filter
# 144	boolsetting.cpp	E:/openmw\apps\opencs\model\prefs\boolsetting.cpp	boolsetting	prefs
# 145	category.cpp	E:/openmw\apps\opencs\model\prefs\category.cpp	category	prefs
# 146	coloursetting.cpp	E:/openmw\apps\opencs\model\prefs\coloursetting.cpp	coloursetting	prefs
# 147	doublesetting.cpp	E:/openmw\apps\opencs\model\prefs\doublesetting.cpp	doublesetting	prefs
# 148	enumsetting.cpp	E:/openmw\apps\opencs\model\prefs\enumsetting.cpp	enumsetting	prefs
# 149	intsetting.cpp	E:/openmw\apps\opencs\model\prefs\intsetting.cpp	intsetting	prefs
# 150	modifiersetting.cpp	E:/openmw\apps\opencs\model\prefs\modifiersetting.cpp	modifiersetting	prefs
# 151	setting.cpp	E:/openmw\apps\opencs\model\prefs\setting.cpp	setting	prefs
# 152	shortcut.cpp	E:/openmw\apps\opencs\model\prefs\shortcut.cpp	shortcut	prefs
# 153	shortcuteventhandler.cpp	E:/openmw\apps\opencs\model\prefs\shortcuteventhandler.cpp	shortcuteventhandler	prefs
# 154	shortcutmanager.cpp	E:/openmw\apps\opencs\model\prefs\shortcutmanager.cpp	shortcutmanager	prefs
# 155	shortcutsetting.cpp	E:/openmw\apps\opencs\model\prefs\shortcutsetting.cpp	shortcutsetting	prefs
# 156	state.cpp	E:/openmw\apps\opencs\model\prefs\state.cpp	state	prefs
# 157	stringsetting.cpp	E:/openmw\apps\opencs\model\prefs\stringsetting.cpp	stringsetting	prefs
# 158	subcategory.cpp	E:/openmw\apps\opencs\model\prefs\subcategory.cpp	subcategory	prefs
# 159	birthsigncheck.cpp	E:/openmw\apps\opencs\model\tools\birthsigncheck.cpp	birthsigncheck	tools
# 160	bodypartcheck.cpp	E:/openmw\apps\opencs\model\tools\bodypartcheck.cpp	bodypartcheck	tools
# 161	classcheck.cpp	E:/openmw\apps\opencs\model\tools\classcheck.cpp	classcheck	tools
# 162	effectlistcheck.cpp	E:/openmw\apps\opencs\model\tools\effectlistcheck.cpp	effectlistcheck	tools
# 163	enchantmentcheck.cpp	E:/openmw\apps\opencs\model\tools\enchantmentcheck.cpp	enchantmentcheck	tools
# 164	factioncheck.cpp	E:/openmw\apps\opencs\model\tools\factioncheck.cpp	factioncheck	tools
# 165	gmstcheck.cpp	E:/openmw\apps\opencs\model\tools\gmstcheck.cpp	gmstcheck	tools
# 166	journalcheck.cpp	E:/openmw\apps\opencs\model\tools\journalcheck.cpp	journalcheck	tools
# 167	magiceffectcheck.cpp	E:/openmw\apps\opencs\model\tools\magiceffectcheck.cpp	magiceffectcheck	tools
# 168	mandatoryid.cpp	E:/openmw\apps\opencs\model\tools\mandatoryid.cpp	mandatoryid	tools
# 169	mergeoperation.cpp	E:/openmw\apps\opencs\model\tools\mergeoperation.cpp	mergeoperation	tools
# 170	mergestages.cpp	E:/openmw\apps\opencs\model\tools\mergestages.cpp	mergestages	tools
# 171	pathgridcheck.cpp	E:/openmw\apps\opencs\model\tools\pathgridcheck.cpp	pathgridcheck	tools
# 172	racecheck.cpp	E:/openmw\apps\opencs\model\tools\racecheck.cpp	racecheck	tools
# 173	referenceablecheck.cpp	E:/openmw\apps\opencs\model\tools\referenceablecheck.cpp	referenceablecheck	tools
# 174	referencecheck.cpp	E:/openmw\apps\opencs\model\tools\referencecheck.cpp	referencecheck	tools
# 175	regioncheck.cpp	E:/openmw\apps\opencs\model\tools\regioncheck.cpp	regioncheck	tools
# 176	reportmodel.cpp	E:/openmw\apps\opencs\model\tools\reportmodel.cpp	reportmodel	tools
# 177	scriptcheck.cpp	E:/openmw\apps\opencs\model\tools\scriptcheck.cpp	scriptcheck	tools
# 178	search.cpp	E:/openmw\apps\opencs\model\tools\search.cpp	search	tools
# 179	searchoperation.cpp	E:/openmw\apps\opencs\model\tools\searchoperation.cpp	searchoperation	tools
# 180	searchstage.cpp	E:/openmw\apps\opencs\model\tools\searchstage.cpp	searchstage	tools
# 181	skillcheck.cpp	E:/openmw\apps\opencs\model\tools\skillcheck.cpp	skillcheck	tools
# 182	soundcheck.cpp	E:/openmw\apps\opencs\model\tools\soundcheck.cpp	soundcheck	tools
# 183	soundgencheck.cpp	E:/openmw\apps\opencs\model\tools\soundgencheck.cpp	soundgencheck	tools
# 184	spellcheck.cpp	E:/openmw\apps\opencs\model\tools\spellcheck.cpp	spellcheck	tools
# 185	startscriptcheck.cpp	E:/openmw\apps\opencs\model\tools\startscriptcheck.cpp	startscriptcheck	tools
# 186	tools.cpp	E:/openmw\apps\opencs\model\tools\tools.cpp	tools	tools
# 187	topicinfocheck.cpp	E:/openmw\apps\opencs\model\tools\topicinfocheck.cpp	topicinfocheck	tools
# 188	actoradapter.cpp	E:/openmw\apps\opencs\model\world\actoradapter.cpp	actoradapter	world
# 189	cell.cpp	E:/openmw\apps\opencs\model\world\cell.cpp	cell	world
# 190	cellcoordinates.cpp	E:/openmw\apps\opencs\model\world\cellcoordinates.cpp	cellcoordinates	world
# 191	cellselection.cpp	E:/openmw\apps\opencs\model\world\cellselection.cpp	cellselection	world
# 192	collectionbase.cpp	E:/openmw\apps\opencs\model\world\collectionbase.cpp	collectionbase	world
# 193	columnbase.cpp	E:/openmw\apps\opencs\model\world\columnbase.cpp	columnbase	world
# 194	columnimp.cpp	E:/openmw\apps\opencs\model\world\columnimp.cpp	columnimp	world
# 195	columns.cpp	E:/openmw\apps\opencs\model\world\columns.cpp	columns	world
# 196	commanddispatcher.cpp	E:/openmw\apps\opencs\model\world\commanddispatcher.cpp	commanddispatcher	world
# 197	commandmacro.cpp	E:/openmw\apps\opencs\model\world\commandmacro.cpp	commandmacro	world
# 198	commands.cpp	E:/openmw\apps\opencs\model\world\commands.cpp	commands	world
# 199	data.cpp	E:/openmw\apps\opencs\model\world\data.cpp	data	world
# 200	defaultgmsts.cpp	E:/openmw\apps\opencs\model\world\defaultgmsts.cpp	defaultgmsts	world
# 201	idcollection.cpp	E:/openmw\apps\opencs\model\world\idcollection.cpp	idcollection	world
# 202	idcompletionmanager.cpp	E:/openmw\apps\opencs\model\world\idcompletionmanager.cpp	idcompletionmanager	world
# 203	idtable.cpp	E:/openmw\apps\opencs\model\world\idtable.cpp	idtable	world
# 204	idtablebase.cpp	E:/openmw\apps\opencs\model\world\idtablebase.cpp	idtablebase	world
# 205	idtableproxymodel.cpp	E:/openmw\apps\opencs\model\world\idtableproxymodel.cpp	idtableproxymodel	world
# 206	idtree.cpp	E:/openmw\apps\opencs\model\world\idtree.cpp	idtree	world
# 207	infocollection.cpp	E:/openmw\apps\opencs\model\world\infocollection.cpp	infocollection	world
# 208	infoselectwrapper.cpp	E:/openmw\apps\opencs\model\world\infoselectwrapper.cpp	infoselectwrapper	world
# 209	infotableproxymodel.cpp	E:/openmw\apps\opencs\model\world\infotableproxymodel.cpp	infotableproxymodel	world
# 210	land.cpp	E:/openmw\apps\opencs\model\world\land.cpp	land	world
# 211	landtexturetableproxymodel.cpp	E:/openmw\apps\opencs\model\world\landtexturetableproxymodel.cpp	landtexturetableproxymodel	world
# 212	metadata.cpp	E:/openmw\apps\opencs\model\world\metadata.cpp	metadata	world
# 213	nestedcoladapterimp.cpp	E:/openmw\apps\opencs\model\world\nestedcoladapterimp.cpp	nestedcoladapterimp	world
# 214	nestedcollection.cpp	E:/openmw\apps\opencs\model\world\nestedcollection.cpp	nestedcollection	world
# 215	nestedinfocollection.cpp	E:/openmw\apps\opencs\model\world\nestedinfocollection.cpp	nestedinfocollection	world
# 216	nestedtableproxymodel.cpp	E:/openmw\apps\opencs\model\world\nestedtableproxymodel.cpp	nestedtableproxymodel	world
# 217	nestedtablewrapper.cpp	E:/openmw\apps\opencs\model\world\nestedtablewrapper.cpp	nestedtablewrapper	world
# 218	pathgrid.cpp	E:/openmw\apps\opencs\model\world\pathgrid.cpp	pathgrid	world
# 219	record.cpp	E:/openmw\apps\opencs\model\world\record.cpp	record	world
# 220	ref.cpp	E:/openmw\apps\opencs\model\world\ref.cpp	ref	world
# 221	refcollection.cpp	E:/openmw\apps\opencs\model\world\refcollection.cpp	refcollection	world
# 222	refidadapterimp.cpp	E:/openmw\apps\opencs\model\world\refidadapterimp.cpp	refidadapterimp	world
# 223	refidcollection.cpp	E:/openmw\apps\opencs\model\world\refidcollection.cpp	refidcollection	world
# 224	refiddata.cpp	E:/openmw\apps\opencs\model\world\refiddata.cpp	refiddata	world
# 225	regionmap.cpp	E:/openmw\apps\opencs\model\world\regionmap.cpp	regionmap	world
# 226	resources.cpp	E:/openmw\apps\opencs\model\world\resources.cpp	resources	world
# 227	resourcesmanager.cpp	E:/openmw\apps\opencs\model\world\resourcesmanager.cpp	resourcesmanager	world
# 228	resourcetable.cpp	E:/openmw\apps\opencs\model\world\resourcetable.cpp	resourcetable	world
# 229	scope.cpp	E:/openmw\apps\opencs\model\world\scope.cpp	scope	world
# 230	scriptcontext.cpp	E:/openmw\apps\opencs\model\world\scriptcontext.cpp	scriptcontext	world
# 231	tablemimedata.cpp	E:/openmw\apps\opencs\model\world\tablemimedata.cpp	tablemimedata	world
# 232	universalid.cpp	E:/openmw\apps\opencs\model\world\universalid.cpp	universalid	world
# 233	adjusterwidget.cpp	E:/openmw\apps\opencs\view\doc\adjusterwidget.cpp	adjusterwidget	doc
# 234	filedialog.cpp	E:/openmw\apps\opencs\view\doc\filedialog.cpp	filedialog	doc
# 235	filewidget.cpp	E:/openmw\apps\opencs\view\doc\filewidget.cpp	filewidget	doc
# 236	globaldebugprofilemenu.cpp	E:/openmw\apps\opencs\view\doc\globaldebugprofilemenu.cpp	globaldebugprofilemenu	doc
# 237	loader.cpp	E:/openmw\apps\opencs\view\doc\loader.cpp	loader	doc
# 238	newgame.cpp	E:/openmw\apps\opencs\view\doc\newgame.cpp	newgame	doc
# 239	operation.cpp	E:/openmw\apps\opencs\view\doc\operation.cpp	operation	doc
# 240	operations.cpp	E:/openmw\apps\opencs\view\doc\operations.cpp	operations	doc
# 241	runlogsubview.cpp	E:/openmw\apps\opencs\view\doc\runlogsubview.cpp	runlogsubview	doc
# 242	sizehint.cpp	E:/openmw\apps\opencs\view\doc\sizehint.cpp	sizehint	doc
# 243	startup.cpp	E:/openmw\apps\opencs\view\doc\startup.cpp	startup	doc
# 244	subview.cpp	E:/openmw\apps\opencs\view\doc\subview.cpp	subview	doc
# 245	subviewfactory.cpp	E:/openmw\apps\opencs\view\doc\subviewfactory.cpp	subviewfactory	doc
# 246	view.cpp	E:/openmw\apps\opencs\view\doc\view.cpp	view	doc
# 247	viewmanager.cpp	E:/openmw\apps\opencs\view\doc\viewmanager.cpp	viewmanager	doc
# 248	editwidget.cpp	E:/openmw\apps\opencs\view\filter\editwidget.cpp	editwidget	filter
# 249	filterbox.cpp	E:/openmw\apps\opencs\view\filter\filterbox.cpp	filterbox	filter
# 250	recordfilterbox.cpp	E:/openmw\apps\opencs\view\filter\recordfilterbox.cpp	recordfilterbox	filter
# 251	contextmenulist.cpp	E:/openmw\apps\opencs\view\prefs\contextmenulist.cpp	contextmenulist	prefs
# 252	dialogue.cpp	E:/openmw\apps\opencs\view\prefs\dialogue.cpp	dialogue	prefs
# 253	keybindingpage.cpp	E:/openmw\apps\opencs\view\prefs\keybindingpage.cpp	keybindingpage	prefs
# 254	page.cpp	E:/openmw\apps\opencs\view\prefs\page.cpp	page	prefs
# 255	pagebase.cpp	E:/openmw\apps\opencs\view\prefs\pagebase.cpp	pagebase	prefs
# 256	actor.cpp	E:/openmw\apps\opencs\view\render\actor.cpp	actor	render
# 257	brushdraw.cpp	E:/openmw\apps\opencs\view\render\brushdraw.cpp	brushdraw	render
# 258	cameracontroller.cpp	E:/openmw\apps\opencs\view\render\cameracontroller.cpp	cameracontroller	render
# 259	cell.cpp	E:/openmw\apps\opencs\view\render\cell.cpp	cell	render
# 260	cellarrow.cpp	E:/openmw\apps\opencs\view\render\cellarrow.cpp	cellarrow	render
# 261	cellborder.cpp	E:/openmw\apps\opencs\view\render\cellborder.cpp	cellborder	render
# 262	cellmarker.cpp	E:/openmw\apps\opencs\view\render\cellmarker.cpp	cellmarker	render
# 263	cellwater.cpp	E:/openmw\apps\opencs\view\render\cellwater.cpp	cellwater	render
# 264	commands.cpp	E:/openmw\apps\opencs\view\render\commands.cpp	commands	render
# 265	editmode.cpp	E:/openmw\apps\opencs\view\render\editmode.cpp	editmode	render
# 266	instancemode.cpp	E:/openmw\apps\opencs\view\render\instancemode.cpp	instancemode	render
# 267	instancemovemode.cpp	E:/openmw\apps\opencs\view\render\instancemovemode.cpp	instancemovemode	render
# 268	instanceselectionmode.cpp	E:/openmw\apps\opencs\view\render\instanceselectionmode.cpp	instanceselectionmode	render
# 269	lighting.cpp	E:/openmw\apps\opencs\view\render\lighting.cpp	lighting	render
# 270	lightingbright.cpp	E:/openmw\apps\opencs\view\render\lightingbright.cpp	lightingbright	render
# 271	lightingday.cpp	E:/openmw\apps\opencs\view\render\lightingday.cpp	lightingday	render
# 272	lightingnight.cpp	E:/openmw\apps\opencs\view\render\lightingnight.cpp	lightingnight	render
# 273	object.cpp	E:/openmw\apps\opencs\view\render\object.cpp	object	render
# 274	orbitcameramode.cpp	E:/openmw\apps\opencs\view\render\orbitcameramode.cpp	orbitcameramode	render
# 275	pagedworldspacewidget.cpp	E:/openmw\apps\opencs\view\render\pagedworldspacewidget.cpp	pagedworldspacewidget	render
# 276	pathgrid.cpp	E:/openmw\apps\opencs\view\render\pathgrid.cpp	pathgrid	render
# 277	pathgridmode.cpp	E:/openmw\apps\opencs\view\render\pathgridmode.cpp	pathgridmode	render
# 278	pathgridselectionmode.cpp	E:/openmw\apps\opencs\view\render\pathgridselectionmode.cpp	pathgridselectionmode	render
# 279	previewwidget.cpp	E:/openmw\apps\opencs\view\render\previewwidget.cpp	previewwidget	render
# 280	scenewidget.cpp	E:/openmw\apps\opencs\view\render\scenewidget.cpp	scenewidget	render
# 281	selectionmode.cpp	E:/openmw\apps\opencs\view\render\selectionmode.cpp	selectionmode	render
# 282	tagbase.cpp	E:/openmw\apps\opencs\view\render\tagbase.cpp	tagbase	render
# 283	terrainselection.cpp	E:/openmw\apps\opencs\view\render\terrainselection.cpp	terrainselection	render
# 284	terrainshapemode.cpp	E:/openmw\apps\opencs\view\render\terrainshapemode.cpp	terrainshapemode	render
# 285	terrainstorage.cpp	E:/openmw\apps\opencs\view\render\terrainstorage.cpp	terrainstorage	render
# 286	terraintexturemode.cpp	E:/openmw\apps\opencs\view\render\terraintexturemode.cpp	terraintexturemode	render
# 287	unpagedworldspacewidget.cpp	E:/openmw\apps\opencs\view\render\unpagedworldspacewidget.cpp	unpagedworldspacewidget	render
# 288	worldspacewidget.cpp	E:/openmw\apps\opencs\view\render\worldspacewidget.cpp	worldspacewidget	render
# 289	merge.cpp	E:/openmw\apps\opencs\view\tools\merge.cpp	merge	tools
# 290	reportsubview.cpp	E:/openmw\apps\opencs\view\tools\reportsubview.cpp	reportsubview	tools
# 291	reporttable.cpp	E:/openmw\apps\opencs\view\tools\reporttable.cpp	reporttable	tools
# 292	searchbox.cpp	E:/openmw\apps\opencs\view\tools\searchbox.cpp	searchbox	tools
# 293	searchsubview.cpp	E:/openmw\apps\opencs\view\tools\searchsubview.cpp	searchsubview	tools
# 294	subviews.cpp	E:/openmw\apps\opencs\view\tools\subviews.cpp	subviews	tools
# 295	coloreditor.cpp	E:/openmw\apps\opencs\view\widget\coloreditor.cpp	coloreditor	widget
# 296	colorpickerpopup.cpp	E:/openmw\apps\opencs\view\widget\colorpickerpopup.cpp	colorpickerpopup	widget
# 297	completerpopup.cpp	E:/openmw\apps\opencs\view\widget\completerpopup.cpp	completerpopup	widget
# 298	droplineedit.cpp	E:/openmw\apps\opencs\view\widget\droplineedit.cpp	droplineedit	widget
# 299	modebutton.cpp	E:/openmw\apps\opencs\view\widget\modebutton.cpp	modebutton	widget
# 300	pushbutton.cpp	E:/openmw\apps\opencs\view\widget\pushbutton.cpp	pushbutton	widget
# 301	scenetool.cpp	E:/openmw\apps\opencs\view\widget\scenetool.cpp	scenetool	widget
# 302	scenetoolbar.cpp	E:/openmw\apps\opencs\view\widget\scenetoolbar.cpp	scenetoolbar	widget
# 303	scenetoolmode.cpp	E:/openmw\apps\opencs\view\widget\scenetoolmode.cpp	scenetoolmode	widget
# 304	scenetoolrun.cpp	E:/openmw\apps\opencs\view\widget\scenetoolrun.cpp	scenetoolrun	widget
# 305	scenetoolshapebrush.cpp	E:/openmw\apps\opencs\view\widget\scenetoolshapebrush.cpp	scenetoolshapebrush	widget
# 306	scenetooltexturebrush.cpp	E:/openmw\apps\opencs\view\widget\scenetooltexturebrush.cpp	scenetooltexturebrush	widget
# 307	scenetooltoggle.cpp	E:/openmw\apps\opencs\view\widget\scenetooltoggle.cpp	scenetooltoggle	widget
# 308	scenetooltoggle2.cpp	E:/openmw\apps\opencs\view\widget\scenetooltoggle2.cpp	scenetooltoggle2	widget
# 309	bodypartcreator.cpp	E:/openmw\apps\opencs\view\world\bodypartcreator.cpp	bodypartcreator	world
# 310	cellcreator.cpp	E:/openmw\apps\opencs\view\world\cellcreator.cpp	cellcreator	world
# 311	colordelegate.cpp	E:/openmw\apps\opencs\view\world\colordelegate.cpp	colordelegate	world
# 312	creator.cpp	E:/openmw\apps\opencs\view\world\creator.cpp	creator	world
# 313	datadisplaydelegate.cpp	E:/openmw\apps\opencs\view\world\datadisplaydelegate.cpp	datadisplaydelegate	world
# 314	dialoguecreator.cpp	E:/openmw\apps\opencs\view\world\dialoguecreator.cpp	dialoguecreator	world
# 315	dialoguespinbox.cpp	E:/openmw\apps\opencs\view\world\dialoguespinbox.cpp	dialoguespinbox	world
# 316	dialoguesubview.cpp	E:/openmw\apps\opencs\view\world\dialoguesubview.cpp	dialoguesubview	world
# 317	dragdroputils.cpp	E:/openmw\apps\opencs\view\world\dragdroputils.cpp	dragdroputils	world
# 318	dragrecordtable.cpp	E:/openmw\apps\opencs\view\world\dragrecordtable.cpp	dragrecordtable	world
# 319	enumdelegate.cpp	E:/openmw\apps\opencs\view\world\enumdelegate.cpp	enumdelegate	world
# 320	extendedcommandconfigurator.cpp	E:/openmw\apps\opencs\view\world\extendedcommandconfigurator.cpp	extendedcommandconfigurator	world
# 321	genericcreator.cpp	E:/openmw\apps\opencs\view\world\genericcreator.cpp	genericcreator	world
# 322	globalcreator.cpp	E:/openmw\apps\opencs\view\world\globalcreator.cpp	globalcreator	world
# 323	idcompletiondelegate.cpp	E:/openmw\apps\opencs\view\world\idcompletiondelegate.cpp	idcompletiondelegate	world
# 324	idtypedelegate.cpp	E:/openmw\apps\opencs\view\world\idtypedelegate.cpp	idtypedelegate	world
# 325	idvalidator.cpp	E:/openmw\apps\opencs\view\world\idvalidator.cpp	idvalidator	world
# 326	infocreator.cpp	E:/openmw\apps\opencs\view\world\infocreator.cpp	infocreator	world
# 327	landcreator.cpp	E:/openmw\apps\opencs\view\world\landcreator.cpp	landcreator	world
# 328	nestedtable.cpp	E:/openmw\apps\opencs\view\world\nestedtable.cpp	nestedtable	world
# 329	pathgridcreator.cpp	E:/openmw\apps\opencs\view\world\pathgridcreator.cpp	pathgridcreator	world
# 330	previewsubview.cpp	E:/openmw\apps\opencs\view\world\previewsubview.cpp	previewsubview	world
# 331	recordbuttonbar.cpp	E:/openmw\apps\opencs\view\world\recordbuttonbar.cpp	recordbuttonbar	world
# 332	recordstatusdelegate.cpp	E:/openmw\apps\opencs\view\world\recordstatusdelegate.cpp	recordstatusdelegate	world
# 333	referenceablecreator.cpp	E:/openmw\apps\opencs\view\world\referenceablecreator.cpp	referenceablecreator	world
# 334	referencecreator.cpp	E:/openmw\apps\opencs\view\world\referencecreator.cpp	referencecreator	world
# 335	regionmap.cpp	E:/openmw\apps\opencs\view\world\regionmap.cpp	regionmap	world
# 336	regionmapsubview.cpp	E:/openmw\apps\opencs\view\world\regionmapsubview.cpp	regionmapsubview	world
# 337	scenesubview.cpp	E:/openmw\apps\opencs\view\world\scenesubview.cpp	scenesubview	world
# 338	scriptedit.cpp	E:/openmw\apps\opencs\view\world\scriptedit.cpp	scriptedit	world
# 339	scripterrortable.cpp	E:/openmw\apps\opencs\view\world\scripterrortable.cpp	scripterrortable	world
# 340	scripthighlighter.cpp	E:/openmw\apps\opencs\view\world\scripthighlighter.cpp	scripthighlighter	world
# 341	scriptsubview.cpp	E:/openmw\apps\opencs\view\world\scriptsubview.cpp	scriptsubview	world
# 342	startscriptcreator.cpp	E:/openmw\apps\opencs\view\world\startscriptcreator.cpp	startscriptcreator	world
# 343	subviews.cpp	E:/openmw\apps\opencs\view\world\subviews.cpp	subviews	world
# 344	table.cpp	E:/openmw\apps\opencs\view\world\table.cpp	table	world
# 345	tablebottombox.cpp	E:/openmw\apps\opencs\view\world\tablebottombox.cpp	tablebottombox	world
# 346	tableeditidaction.cpp	E:/openmw\apps\opencs\view\world\tableeditidaction.cpp	tableeditidaction	world
# 347	tableheadermouseeventhandler.cpp	E:/openmw\apps\opencs\view\world\tableheadermouseeventhandler.cpp	tableheadermouseeventhandler	world
# 348	tablesubview.cpp	E:/openmw\apps\opencs\view\world\tablesubview.cpp	tablesubview	world
# 349	util.cpp	E:/openmw\apps\opencs\view\world\util.cpp	util	world
# 350	vartypedelegate.cpp	E:/openmw\apps\opencs\view\world\vartypedelegate.cpp	vartypedelegate	world
# 351	main.cpp	E:/openmw\apps\opencs_tests\main.cpp	main	opencs_tests
# 352	testinfocollection.cpp	E:/openmw\apps\opencs_tests\model\world\testinfocollection.cpp	testinfocollection	world
# 353	testuniversalid.cpp	E:/openmw\apps\opencs_tests\model\world\testuniversalid.cpp	testuniversalid	world
# 354	android_main.cpp	E:/openmw\apps\openmw\android_main.cpp	android_main	openmw
# 355	engine.cpp	E:/openmw\apps\openmw\engine.cpp	engine	openmw
# 356	main.cpp	E:/openmw\apps\openmw\main.cpp	main	openmw
# 357	options.cpp	E:/openmw\apps\openmw\options.cpp	options	openmw
# 358	environment.cpp	E:/openmw\apps\openmw\mwbase\environment.cpp	environment	mwbase
# 359	activator.cpp	E:/openmw\apps\openmw\mwclass\activator.cpp	activator	mwclass
# 360	actor.cpp	E:/openmw\apps\openmw\mwclass\actor.cpp	actor	mwclass
# 361	apparatus.cpp	E:/openmw\apps\openmw\mwclass\apparatus.cpp	apparatus	mwclass
# 362	armor.cpp	E:/openmw\apps\openmw\mwclass\armor.cpp	armor	mwclass
# 363	bodypart.cpp	E:/openmw\apps\openmw\mwclass\bodypart.cpp	bodypart	mwclass
# 364	book.cpp	E:/openmw\apps\openmw\mwclass\book.cpp	book	mwclass
# 365	classes.cpp	E:/openmw\apps\openmw\mwclass\classes.cpp	classes	mwclass
# 366	clothing.cpp	E:/openmw\apps\openmw\mwclass\clothing.cpp	clothing	mwclass
# 367	container.cpp	E:/openmw\apps\openmw\mwclass\container.cpp	container	mwclass
# 368	creature.cpp	E:/openmw\apps\openmw\mwclass\creature.cpp	creature	mwclass
# 369	creaturelevlist.cpp	E:/openmw\apps\openmw\mwclass\creaturelevlist.cpp	creaturelevlist	mwclass
# 370	door.cpp	E:/openmw\apps\openmw\mwclass\door.cpp	door	mwclass
# 371	esm4base.cpp	E:/openmw\apps\openmw\mwclass\esm4base.cpp	esm4base	mwclass
# 372	esm4npc.cpp	E:/openmw\apps\openmw\mwclass\esm4npc.cpp	esm4npc	mwclass
# 373	ingredient.cpp	E:/openmw\apps\openmw\mwclass\ingredient.cpp	ingredient	mwclass
# 374	itemlevlist.cpp	E:/openmw\apps\openmw\mwclass\itemlevlist.cpp	itemlevlist	mwclass
# 375	light.cpp	E:/openmw\apps\openmw\mwclass\light.cpp	light	mwclass
# 376	light4.cpp	E:/openmw\apps\openmw\mwclass\light4.cpp	light4	mwclass
# 377	lockpick.cpp	E:/openmw\apps\openmw\mwclass\lockpick.cpp	lockpick	mwclass
# 378	misc.cpp	E:/openmw\apps\openmw\mwclass\misc.cpp	misc	mwclass
# 379	npc.cpp	E:/openmw\apps\openmw\mwclass\npc.cpp	npc	mwclass
# 380	potion.cpp	E:/openmw\apps\openmw\mwclass\potion.cpp	potion	mwclass
# 381	probe.cpp	E:/openmw\apps\openmw\mwclass\probe.cpp	probe	mwclass
# 382	repair.cpp	E:/openmw\apps\openmw\mwclass\repair.cpp	repair	mwclass
# 383	static.cpp	E:/openmw\apps\openmw\mwclass\static.cpp	static	mwclass
# 384	weapon.cpp	E:/openmw\apps\openmw\mwclass\weapon.cpp	weapon	mwclass
# 385	dialoguemanagerimp.cpp	E:/openmw\apps\openmw\mwdialogue\dialoguemanagerimp.cpp	dialoguemanagerimp	mwdialogue
# 386	filter.cpp	E:/openmw\apps\openmw\mwdialogue\filter.cpp	filter	mwdialogue
# 387	hypertextparser.cpp	E:/openmw\apps\openmw\mwdialogue\hypertextparser.cpp	hypertextparser	mwdialogue
# 388	journalentry.cpp	E:/openmw\apps\openmw\mwdialogue\journalentry.cpp	journalentry	mwdialogue
# 389	journalimp.cpp	E:/openmw\apps\openmw\mwdialogue\journalimp.cpp	journalimp	mwdialogue
# 390	quest.cpp	E:/openmw\apps\openmw\mwdialogue\quest.cpp	quest	mwdialogue
# 391	scripttest.cpp	E:/openmw\apps\openmw\mwdialogue\scripttest.cpp	scripttest	mwdialogue
# 392	selectwrapper.cpp	E:/openmw\apps\openmw\mwdialogue\selectwrapper.cpp	selectwrapper	mwdialogue
# 393	topic.cpp	E:/openmw\apps\openmw\mwdialogue\topic.cpp	topic	mwdialogue
# 394	alchemywindow.cpp	E:/openmw\apps\openmw\mwgui\alchemywindow.cpp	alchemywindow	mwgui
# 395	backgroundimage.cpp	E:/openmw\apps\openmw\mwgui\backgroundimage.cpp	backgroundimage	mwgui
# 396	birth.cpp	E:/openmw\apps\openmw\mwgui\birth.cpp	birth	mwgui
# 397	bookpage.cpp	E:/openmw\apps\openmw\mwgui\bookpage.cpp	bookpage	mwgui
# 398	bookwindow.cpp	E:/openmw\apps\openmw\mwgui\bookwindow.cpp	bookwindow	mwgui
# 399	charactercreation.cpp	E:/openmw\apps\openmw\mwgui\charactercreation.cpp	charactercreation	mwgui
# 400	class.cpp	E:/openmw\apps\openmw\mwgui\class.cpp	class	mwgui
# 401	companionitemmodel.cpp	E:/openmw\apps\openmw\mwgui\companionitemmodel.cpp	companionitemmodel	mwgui
# 402	companionwindow.cpp	E:/openmw\apps\openmw\mwgui\companionwindow.cpp	companionwindow	mwgui
# 403	confirmationdialog.cpp	E:/openmw\apps\openmw\mwgui\confirmationdialog.cpp	confirmationdialog	mwgui
# 404	console.cpp	E:/openmw\apps\openmw\mwgui\console.cpp	console	mwgui
# 405	container.cpp	E:/openmw\apps\openmw\mwgui\container.cpp	container	mwgui
# 406	containeritemmodel.cpp	E:/openmw\apps\openmw\mwgui\containeritemmodel.cpp	containeritemmodel	mwgui
# 407	controllers.cpp	E:/openmw\apps\openmw\mwgui\controllers.cpp	controllers	mwgui
# 408	countdialog.cpp	E:/openmw\apps\openmw\mwgui\countdialog.cpp	countdialog	mwgui
# 409	cursor.cpp	E:/openmw\apps\openmw\mwgui\cursor.cpp	cursor	mwgui
# 410	debugwindow.cpp	E:/openmw\apps\openmw\mwgui\debugwindow.cpp	debugwindow	mwgui
# 411	dialogue.cpp	E:/openmw\apps\openmw\mwgui\dialogue.cpp	dialogue	mwgui
# 412	draganddrop.cpp	E:/openmw\apps\openmw\mwgui\draganddrop.cpp	draganddrop	mwgui
# 413	enchantingdialog.cpp	E:/openmw\apps\openmw\mwgui\enchantingdialog.cpp	enchantingdialog	mwgui
# 414	exposedwindow.cpp	E:/openmw\apps\openmw\mwgui\exposedwindow.cpp	exposedwindow	mwgui
# 415	formatting.cpp	E:/openmw\apps\openmw\mwgui\formatting.cpp	formatting	mwgui
# 416	hud.cpp	E:/openmw\apps\openmw\mwgui\hud.cpp	hud	mwgui
# 417	inventoryitemmodel.cpp	E:/openmw\apps\openmw\mwgui\inventoryitemmodel.cpp	inventoryitemmodel	mwgui
# 418	inventorywindow.cpp	E:/openmw\apps\openmw\mwgui\inventorywindow.cpp	inventorywindow	mwgui
# 419	itemchargeview.cpp	E:/openmw\apps\openmw\mwgui\itemchargeview.cpp	itemchargeview	mwgui
# 420	itemmodel.cpp	E:/openmw\apps\openmw\mwgui\itemmodel.cpp	itemmodel	mwgui
# 421	itemselection.cpp	E:/openmw\apps\openmw\mwgui\itemselection.cpp	itemselection	mwgui
# 422	itemview.cpp	E:/openmw\apps\openmw\mwgui\itemview.cpp	itemview	mwgui
# 423	itemwidget.cpp	E:/openmw\apps\openmw\mwgui\itemwidget.cpp	itemwidget	mwgui
# 424	jailscreen.cpp	E:/openmw\apps\openmw\mwgui\jailscreen.cpp	jailscreen	mwgui
# 425	journalbooks.cpp	E:/openmw\apps\openmw\mwgui\journalbooks.cpp	journalbooks	mwgui
# 426	journalviewmodel.cpp	E:/openmw\apps\openmw\mwgui\journalviewmodel.cpp	journalviewmodel	mwgui
# 427	journalwindow.cpp	E:/openmw\apps\openmw\mwgui\journalwindow.cpp	journalwindow	mwgui
# 428	keyboardnavigation.cpp	E:/openmw\apps\openmw\mwgui\keyboardnavigation.cpp	keyboardnavigation	mwgui
# 429	layout.cpp	E:/openmw\apps\openmw\mwgui\layout.cpp	layout	mwgui
# 430	levelupdialog.cpp	E:/openmw\apps\openmw\mwgui\levelupdialog.cpp	levelupdialog	mwgui
# 431	loadingscreen.cpp	E:/openmw\apps\openmw\mwgui\loadingscreen.cpp	loadingscreen	mwgui
# 432	mainmenu.cpp	E:/openmw\apps\openmw\mwgui\mainmenu.cpp	mainmenu	mwgui
# 433	mapwindow.cpp	E:/openmw\apps\openmw\mwgui\mapwindow.cpp	mapwindow	mwgui
# 434	merchantrepair.cpp	E:/openmw\apps\openmw\mwgui\merchantrepair.cpp	merchantrepair	mwgui
# 435	messagebox.cpp	E:/openmw\apps\openmw\mwgui\messagebox.cpp	messagebox	mwgui
# 436	pickpocketitemmodel.cpp	E:/openmw\apps\openmw\mwgui\pickpocketitemmodel.cpp	pickpocketitemmodel	mwgui
# 437	postprocessorhud.cpp	E:/openmw\apps\openmw\mwgui\postprocessorhud.cpp	postprocessorhud	mwgui
# 438	quickkeysmenu.cpp	E:/openmw\apps\openmw\mwgui\quickkeysmenu.cpp	quickkeysmenu	mwgui
# 439	race.cpp	E:/openmw\apps\openmw\mwgui\race.cpp	race	mwgui
# 440	recharge.cpp	E:/openmw\apps\openmw\mwgui\recharge.cpp	recharge	mwgui
# 441	referenceinterface.cpp	E:/openmw\apps\openmw\mwgui\referenceinterface.cpp	referenceinterface	mwgui
# 442	repair.cpp	E:/openmw\apps\openmw\mwgui\repair.cpp	repair	mwgui
# 443	resourceskin.cpp	E:/openmw\apps\openmw\mwgui\resourceskin.cpp	resourceskin	mwgui
# 444	review.cpp	E:/openmw\apps\openmw\mwgui\review.cpp	review	mwgui
# 445	savegamedialog.cpp	E:/openmw\apps\openmw\mwgui\savegamedialog.cpp	savegamedialog	mwgui
# 446	screenfader.cpp	E:/openmw\apps\openmw\mwgui\screenfader.cpp	screenfader	mwgui
# 447	scrollwindow.cpp	E:/openmw\apps\openmw\mwgui\scrollwindow.cpp	scrollwindow	mwgui
# 448	settings.cpp	E:/openmw\apps\openmw\mwgui\settings.cpp	settings	mwgui
# 449	settingswindow.cpp	E:/openmw\apps\openmw\mwgui\settingswindow.cpp	settingswindow	mwgui
# 450	sortfilteritemmodel.cpp	E:/openmw\apps\openmw\mwgui\sortfilteritemmodel.cpp	sortfilteritemmodel	mwgui
# 451	soulgemdialog.cpp	E:/openmw\apps\openmw\mwgui\soulgemdialog.cpp	soulgemdialog	mwgui
# 452	spellbuyingwindow.cpp	E:/openmw\apps\openmw\mwgui\spellbuyingwindow.cpp	spellbuyingwindow	mwgui
# 453	spellcreationdialog.cpp	E:/openmw\apps\openmw\mwgui\spellcreationdialog.cpp	spellcreationdialog	mwgui
# 454	spellicons.cpp	E:/openmw\apps\openmw\mwgui\spellicons.cpp	spellicons	mwgui
# 455	spellmodel.cpp	E:/openmw\apps\openmw\mwgui\spellmodel.cpp	spellmodel	mwgui
# 456	spellview.cpp	E:/openmw\apps\openmw\mwgui\spellview.cpp	spellview	mwgui
# 457	spellwindow.cpp	E:/openmw\apps\openmw\mwgui\spellwindow.cpp	spellwindow	mwgui
# 458	statswatcher.cpp	E:/openmw\apps\openmw\mwgui\statswatcher.cpp	statswatcher	mwgui
# 459	statswindow.cpp	E:/openmw\apps\openmw\mwgui\statswindow.cpp	statswindow	mwgui
# 460	textcolours.cpp	E:/openmw\apps\openmw\mwgui\textcolours.cpp	textcolours	mwgui
# 461	textinput.cpp	E:/openmw\apps\openmw\mwgui\textinput.cpp	textinput	mwgui
# 462	timeadvancer.cpp	E:/openmw\apps\openmw\mwgui\timeadvancer.cpp	timeadvancer	mwgui
# 463	tooltips.cpp	E:/openmw\apps\openmw\mwgui\tooltips.cpp	tooltips	mwgui
# 464	tradeitemmodel.cpp	E:/openmw\apps\openmw\mwgui\tradeitemmodel.cpp	tradeitemmodel	mwgui
# 465	tradewindow.cpp	E:/openmw\apps\openmw\mwgui\tradewindow.cpp	tradewindow	mwgui
# 466	trainingwindow.cpp	E:/openmw\apps\openmw\mwgui\trainingwindow.cpp	trainingwindow	mwgui
# 467	travelwindow.cpp	E:/openmw\apps\openmw\mwgui\travelwindow.cpp	travelwindow	mwgui
# 468	videowidget.cpp	E:/openmw\apps\openmw\mwgui\videowidget.cpp	videowidget	mwgui
# 469	waitdialog.cpp	E:/openmw\apps\openmw\mwgui\waitdialog.cpp	waitdialog	mwgui
# 470	widgets.cpp	E:/openmw\apps\openmw\mwgui\widgets.cpp	widgets	mwgui
# 471	windowbase.cpp	E:/openmw\apps\openmw\mwgui\windowbase.cpp	windowbase	mwgui
# 472	windowmanagerimp.cpp	E:/openmw\apps\openmw\mwgui\windowmanagerimp.cpp	windowmanagerimp	mwgui
# 473	windowpinnablebase.cpp	E:/openmw\apps\openmw\mwgui\windowpinnablebase.cpp	windowpinnablebase	mwgui
# 474	actionmanager.cpp	E:/openmw\apps\openmw\mwinput\actionmanager.cpp	actionmanager	mwinput
# 475	bindingsmanager.cpp	E:/openmw\apps\openmw\mwinput\bindingsmanager.cpp	bindingsmanager	mwinput
# 476	controllermanager.cpp	E:/openmw\apps\openmw\mwinput\controllermanager.cpp	controllermanager	mwinput
# 477	controlswitch.cpp	E:/openmw\apps\openmw\mwinput\controlswitch.cpp	controlswitch	mwinput
# 478	gyromanager.cpp	E:/openmw\apps\openmw\mwinput\gyromanager.cpp	gyromanager	mwinput
# 479	inputmanagerimp.cpp	E:/openmw\apps\openmw\mwinput\inputmanagerimp.cpp	inputmanagerimp	mwinput
# 480	keyboardmanager.cpp	E:/openmw\apps\openmw\mwinput\keyboardmanager.cpp	keyboardmanager	mwinput
# 481	mousemanager.cpp	E:/openmw\apps\openmw\mwinput\mousemanager.cpp	mousemanager	mwinput
# 482	sensormanager.cpp	E:/openmw\apps\openmw\mwinput\sensormanager.cpp	sensormanager	mwinput
# 483	animationbindings.cpp	E:/openmw\apps\openmw\mwlua\animationbindings.cpp	animationbindings	mwlua
# 484	birthsignbindings.cpp	E:/openmw\apps\openmw\mwlua\birthsignbindings.cpp	birthsignbindings	mwlua
# 485	camerabindings.cpp	E:/openmw\apps\openmw\mwlua\camerabindings.cpp	camerabindings	mwlua
# 486	cellbindings.cpp	E:/openmw\apps\openmw\mwlua\cellbindings.cpp	cellbindings	mwlua
# 487	classbindings.cpp	E:/openmw\apps\openmw\mwlua\classbindings.cpp	classbindings	mwlua
# 488	corebindings.cpp	E:/openmw\apps\openmw\mwlua\corebindings.cpp	corebindings	mwlua
# 489	debugbindings.cpp	E:/openmw\apps\openmw\mwlua\debugbindings.cpp	debugbindings	mwlua
# 490	dialoguebindings.cpp	E:/openmw\apps\openmw\mwlua\dialoguebindings.cpp	dialoguebindings	mwlua
# 491	engineevents.cpp	E:/openmw\apps\openmw\mwlua\engineevents.cpp	engineevents	mwlua
# 492	factionbindings.cpp	E:/openmw\apps\openmw\mwlua\factionbindings.cpp	factionbindings	mwlua
# 493	inputbindings.cpp	E:/openmw\apps\openmw\mwlua\inputbindings.cpp	inputbindings	mwlua
# 494	itemdata.cpp	E:/openmw\apps\openmw\mwlua\itemdata.cpp	itemdata	mwlua
# 495	localscripts.cpp	E:/openmw\apps\openmw\mwlua\localscripts.cpp	localscripts	mwlua
# 496	luabindings.cpp	E:/openmw\apps\openmw\mwlua\luabindings.cpp	luabindings	mwlua
# 497	luaevents.cpp	E:/openmw\apps\openmw\mwlua\luaevents.cpp	luaevents	mwlua
# 498	luamanagerimp.cpp	E:/openmw\apps\openmw\mwlua\luamanagerimp.cpp	luamanagerimp	mwlua
# 499	magicbindings.cpp	E:/openmw\apps\openmw\mwlua\magicbindings.cpp	magicbindings	mwlua
# 500	markupbindings.cpp	E:/openmw\apps\openmw\mwlua\markupbindings.cpp	markupbindings	mwlua
# 501	menuscripts.cpp	E:/openmw\apps\openmw\mwlua\menuscripts.cpp	menuscripts	mwlua
# 502	mwscriptbindings.cpp	E:/openmw\apps\openmw\mwlua\mwscriptbindings.cpp	mwscriptbindings	mwlua
# 503	nearbybindings.cpp	E:/openmw\apps\openmw\mwlua\nearbybindings.cpp	nearbybindings	mwlua
# 504	objectbindings.cpp	E:/openmw\apps\openmw\mwlua\objectbindings.cpp	objectbindings	mwlua
# 505	objectlists.cpp	E:/openmw\apps\openmw\mwlua\objectlists.cpp	objectlists	mwlua
# 506	postprocessingbindings.cpp	E:/openmw\apps\openmw\mwlua\postprocessingbindings.cpp	postprocessingbindings	mwlua
# 507	racebindings.cpp	E:/openmw\apps\openmw\mwlua\racebindings.cpp	racebindings	mwlua
# 508	soundbindings.cpp	E:/openmw\apps\openmw\mwlua\soundbindings.cpp	soundbindings	mwlua
# 509	stats.cpp	E:/openmw\apps\openmw\mwlua\stats.cpp	stats	mwlua
# 510	uibindings.cpp	E:/openmw\apps\openmw\mwlua\uibindings.cpp	uibindings	mwlua
# 511	userdataserializer.cpp	E:/openmw\apps\openmw\mwlua\userdataserializer.cpp	userdataserializer	mwlua
# 512	vfsbindings.cpp	E:/openmw\apps\openmw\mwlua\vfsbindings.cpp	vfsbindings	mwlua
# 513	worker.cpp	E:/openmw\apps\openmw\mwlua\worker.cpp	worker	mwlua
# 514	worldbindings.cpp	E:/openmw\apps\openmw\mwlua\worldbindings.cpp	worldbindings	mwlua
# 515	activator.cpp	E:/openmw\apps\openmw\mwlua\types\activator.cpp	activator	types
# 516	actor.cpp	E:/openmw\apps\openmw\mwlua\types\actor.cpp	actor	types
# 517	apparatus.cpp	E:/openmw\apps\openmw\mwlua\types\apparatus.cpp	apparatus	types
# 518	armor.cpp	E:/openmw\apps\openmw\mwlua\types\armor.cpp	armor	types
# 519	book.cpp	E:/openmw\apps\openmw\mwlua\types\book.cpp	book	types
# 520	clothing.cpp	E:/openmw\apps\openmw\mwlua\types\clothing.cpp	clothing	types
# 521	container.cpp	E:/openmw\apps\openmw\mwlua\types\container.cpp	container	types
# 522	creature.cpp	E:/openmw\apps\openmw\mwlua\types\creature.cpp	creature	types
# 523	door.cpp	E:/openmw\apps\openmw\mwlua\types\door.cpp	door	types
# 524	ingredient.cpp	E:/openmw\apps\openmw\mwlua\types\ingredient.cpp	ingredient	types
# 525	item.cpp	E:/openmw\apps\openmw\mwlua\types\item.cpp	item	types
# 526	levelledlist.cpp	E:/openmw\apps\openmw\mwlua\types\levelledlist.cpp	levelledlist	types
# 527	light.cpp	E:/openmw\apps\openmw\mwlua\types\light.cpp	light	types
# 528	lockable.cpp	E:/openmw\apps\openmw\mwlua\types\lockable.cpp	lockable	types
# 529	lockpick.cpp	E:/openmw\apps\openmw\mwlua\types\lockpick.cpp	lockpick	types
# 530	misc.cpp	E:/openmw\apps\openmw\mwlua\types\misc.cpp	misc	types
# 531	npc.cpp	E:/openmw\apps\openmw\mwlua\types\npc.cpp	npc	types
# 532	player.cpp	E:/openmw\apps\openmw\mwlua\types\player.cpp	player	types
# 533	potion.cpp	E:/openmw\apps\openmw\mwlua\types\potion.cpp	potion	types
# 534	probe.cpp	E:/openmw\apps\openmw\mwlua\types\probe.cpp	probe	types
# 535	repair.cpp	E:/openmw\apps\openmw\mwlua\types\repair.cpp	repair	types
# 536	static.cpp	E:/openmw\apps\openmw\mwlua\types\static.cpp	static	types
# 537	terminal.cpp	E:/openmw\apps\openmw\mwlua\types\terminal.cpp	terminal	types
# 538	types.cpp	E:/openmw\apps\openmw\mwlua\types\types.cpp	types	types
# 539	weapon.cpp	E:/openmw\apps\openmw\mwlua\types\weapon.cpp	weapon	types
# 540	activespells.cpp	E:/openmw\apps\openmw\mwmechanics\activespells.cpp	activespells	mwmechanics
# 541	actors.cpp	E:/openmw\apps\openmw\mwmechanics\actors.cpp	actors	mwmechanics
# 542	actorutil.cpp	E:/openmw\apps\openmw\mwmechanics\actorutil.cpp	actorutil	mwmechanics
# 543	aiactivate.cpp	E:/openmw\apps\openmw\mwmechanics\aiactivate.cpp	aiactivate	mwmechanics
# 544	aiavoiddoor.cpp	E:/openmw\apps\openmw\mwmechanics\aiavoiddoor.cpp	aiavoiddoor	mwmechanics
# 545	aibreathe.cpp	E:/openmw\apps\openmw\mwmechanics\aibreathe.cpp	aibreathe	mwmechanics
# 546	aicast.cpp	E:/openmw\apps\openmw\mwmechanics\aicast.cpp	aicast	mwmechanics
# ...
# 3095	Placer.cpp	E:/openmw\OpenSceneGraph\src\osgWrappers\serializers\osgParticle\Placer.cpp	Placer	osgParticle
# 3096	PointPlacer.cpp	E:/openmw\OpenSceneGraph\src\osgWrappers\serializers\osgParticle\PointPlacer.cpp	PointPlacer	osgParticle
# 3097	PrecipitationEffect.cpp	E:/openmw\OpenSceneGraph\src\osgWrappers\serializers\osgParticle\PrecipitationEffect.cpp	PrecipitationEffect	osgParticle
# 3098	Program.cpp	E:/openmw\OpenSceneGraph\src\osgWrappers\serializers\osgParticle\Program.cpp	Program	osgParticle
# 3099	RadialShooter.cpp	E:/openmw\OpenSceneGraph\src\osgWrappers\serializers\osgParticle\RadialShooter.cpp	RadialShooter	osgParticle
# 3100	RandomRateCounter.cpp	E:/openmw\OpenSceneGraph\src\osgWrappers\serializers\osgParticle\RandomRateCounter.cpp	RandomRateCounter	osgParticle
# 3101	SectorPlacer.cpp	E:/openmw\OpenSceneGraph\src\osgWrappers\serializers\osgParticle\SectorPlacer.cpp	SectorPlacer	osgParticle
# 3102	SegmentPlacer.cpp	E:/openmw\OpenSceneGraph\src\osgWrappers\serializers\osgParticle\SegmentPlacer.cpp	SegmentPlacer	osgParticle
# 3103	Shooter.cpp	E:/openmw\OpenSceneGraph\src\osgWrappers\serializers\osgParticle\Shooter.cpp	Shooter	osgParticle
# 3104	SinkOperator.cpp	E:/openmw\OpenSceneGraph\src\osgWrappers\serializers\osgParticle\SinkOperator.cpp	SinkOperator	osgParticle
# 3105	SmokeEffect.cpp	E:/openmw\OpenSceneGraph\src\osgWrappers\serializers\osgParticle\SmokeEffect.cpp	SmokeEffect	osgParticle
# 3106	SmokeTrailEffect.cpp	E:/openmw\OpenSceneGraph\src\osgWrappers\serializers\osgParticle\SmokeTrailEffect.cpp	SmokeTrailEffect	osgParticle
# 3107	VariableRateCounter.cpp	E:/openmw\OpenSceneGraph\src\osgWrappers\serializers\osgParticle\VariableRateCounter.cpp	VariableRateCounter	osgParticle
# 3108	DebugShadowMap.cpp	E:/openmw\OpenSceneGraph\src\osgWrappers\serializers\osgShadow\DebugShadowMap.cpp	DebugShadowMap	osgShadow
# 3109	LibraryWrapper.cpp	E:/openmw\OpenSceneGraph\src\osgWrappers\serializers\osgShadow\LibraryWrapper.cpp	LibraryWrapper	osgShadow
# 3110	LightSpacePerspectiveShadowMapCB.cpp	E:/openmw\OpenSceneGraph\src\osgWrappers\serializers\osgShadow\LightSpacePerspectiveShadowMapCB.cpp	LightSpacePerspectiveShadowMapCB	osgShadow
# 3111	LightSpacePerspectiveShadowMapDB.cpp	E:/openmw\OpenSceneGraph\src\osgWrappers\serializers\osgShadow\LightSpacePerspectiveShadowMapDB.cpp	LightSpacePerspectiveShadowMapDB	osgShadow
# 3112	LightSpacePerspectiveShadowMapVB.cpp	E:/openmw\OpenSceneGraph\src\osgWrappers\serializers\osgShadow\LightSpacePerspectiveShadowMapVB.cpp	LightSpacePerspectiveShadowMapVB	osgShadow
# 3113	MinimalCullBoundsShadowMap.cpp	E:/openmw\OpenSceneGraph\src\osgWrappers\serializers\osgShadow\MinimalCullBoundsShadowMap.cpp	MinimalCullBoundsShadowMap	osgShadow
# 3114	MinimalDrawBoundsShadowMap.cpp	E:/openmw\OpenSceneGraph\src\osgWrappers\serializers\osgShadow\MinimalDrawBoundsShadowMap.cpp	MinimalDrawBoundsShadowMap	osgShadow
# 3115	MinimalShadowMap.cpp	E:/openmw\OpenSceneGraph\src\osgWrappers\serializers\osgShadow\MinimalShadowMap.cpp	MinimalShadowMap	osgShadow
# 3116	ParallelSplitShadowMap.cpp	E:/openmw\OpenSceneGraph\src\osgWrappers\serializers\osgShadow\ParallelSplitShadowMap.cpp	ParallelSplitShadowMap	osgShadow
# 3117	ShadowedScene.cpp	E:/openmw\OpenSceneGraph\src\osgWrappers\serializers\osgShadow\ShadowedScene.cpp	ShadowedScene	osgShadow
# 3118	ShadowMap.cpp	E:/openmw\OpenSceneGraph\src\osgWrappers\serializers\osgShadow\ShadowMap.cpp	ShadowMap	osgShadow
# 3119	ShadowTechnique.cpp	E:/openmw\OpenSceneGraph\src\osgWrappers\serializers\osgShadow\ShadowTechnique.cpp	ShadowTechnique	osgShadow
# 3120	ShadowTexture.cpp	E:/openmw\OpenSceneGraph\src\osgWrappers\serializers\osgShadow\ShadowTexture.cpp	ShadowTexture	osgShadow
# 3121	ShadowVolume.cpp	E:/openmw\OpenSceneGraph\src\osgWrappers\serializers\osgShadow\ShadowVolume.cpp	ShadowVolume	osgShadow
# 3122	SoftShadowMap.cpp	E:/openmw\OpenSceneGraph\src\osgWrappers\serializers\osgShadow\SoftShadowMap.cpp	SoftShadowMap	osgShadow
# 3123	StandardShadowMap.cpp	E:/openmw\OpenSceneGraph\src\osgWrappers\serializers\osgShadow\StandardShadowMap.cpp	StandardShadowMap	osgShadow
# 3124	ViewDependentShadowTechnique.cpp	E:/openmw\OpenSceneGraph\src\osgWrappers\serializers\osgShadow\ViewDependentShadowTechnique.cpp	ViewDependentShadowTechnique	osgShadow
# 3125	AzimElevationSector.cpp	E:/openmw\OpenSceneGraph\src\osgWrappers\serializers\osgSim\AzimElevationSector.cpp	AzimElevationSector	osgSim
# 3126	AzimSector.cpp	E:/openmw\OpenSceneGraph\src\osgWrappers\serializers\osgSim\AzimSector.cpp	AzimSector	osgSim
# 3127	BlinkSequence.cpp	E:/openmw\OpenSceneGraph\src\osgWrappers\serializers\osgSim\BlinkSequence.cpp	BlinkSequence	osgSim
# 3128	ConeSector.cpp	E:/openmw\OpenSceneGraph\src\osgWrappers\serializers\osgSim\ConeSector.cpp	ConeSector	osgSim
# 3129	DirectionalSector.cpp	E:/openmw\OpenSceneGraph\src\osgWrappers\serializers\osgSim\DirectionalSector.cpp	DirectionalSector	osgSim
# 3130	DOFTransform.cpp	E:/openmw\OpenSceneGraph\src\osgWrappers\serializers\osgSim\DOFTransform.cpp	DOFTransform	osgSim
# 3131	ElevationSector.cpp	E:/openmw\OpenSceneGraph\src\osgWrappers\serializers\osgSim\ElevationSector.cpp	ElevationSector	osgSim
# 3132	Impostor.cpp	E:/openmw\OpenSceneGraph\src\osgWrappers\serializers\osgSim\Impostor.cpp	Impostor	osgSim
# 3133	LibraryWrapper.cpp	E:/openmw\OpenSceneGraph\src\osgWrappers\serializers\osgSim\LibraryWrapper.cpp	LibraryWrapper	osgSim
# 3134	LightPointNode.cpp	E:/openmw\OpenSceneGraph\src\osgWrappers\serializers\osgSim\LightPointNode.cpp	LightPointNode	osgSim
# 3135	LightPointSystem.cpp	E:/openmw\OpenSceneGraph\src\osgWrappers\serializers\osgSim\LightPointSystem.cpp	LightPointSystem	osgSim
# 3136	MultiSwitch.cpp	E:/openmw\OpenSceneGraph\src\osgWrappers\serializers\osgSim\MultiSwitch.cpp	MultiSwitch	osgSim
# 3137	ObjectRecordData.cpp	E:/openmw\OpenSceneGraph\src\osgWrappers\serializers\osgSim\ObjectRecordData.cpp	ObjectRecordData	osgSim
# 3138	OverlayNode.cpp	E:/openmw\OpenSceneGraph\src\osgWrappers\serializers\osgSim\OverlayNode.cpp	OverlayNode	osgSim
# 3139	ScalarBar.cpp	E:/openmw\OpenSceneGraph\src\osgWrappers\serializers\osgSim\ScalarBar.cpp	ScalarBar	osgSim
# 3140	Sector.cpp	E:/openmw\OpenSceneGraph\src\osgWrappers\serializers\osgSim\Sector.cpp	Sector	osgSim
# 3141	SequenceGroup.cpp	E:/openmw\OpenSceneGraph\src\osgWrappers\serializers\osgSim\SequenceGroup.cpp	SequenceGroup	osgSim
# 3142	ShapeAttributeList.cpp	E:/openmw\OpenSceneGraph\src\osgWrappers\serializers\osgSim\ShapeAttributeList.cpp	ShapeAttributeList	osgSim
# 3143	SphereSegment.cpp	E:/openmw\OpenSceneGraph\src\osgWrappers\serializers\osgSim\SphereSegment.cpp	SphereSegment	osgSim
# 3144	VisibilityGroup.cpp	E:/openmw\OpenSceneGraph\src\osgWrappers\serializers\osgSim\VisibilityGroup.cpp	VisibilityGroup	osgSim
# 3145	CompositeLayer.cpp	E:/openmw\OpenSceneGraph\src\osgWrappers\serializers\osgTerrain\CompositeLayer.cpp	CompositeLayer	osgTerrain
# 3146	ContourLayer.cpp	E:/openmw\OpenSceneGraph\src\osgWrappers\serializers\osgTerrain\ContourLayer.cpp	ContourLayer	osgTerrain
# 3147	DisplacementMappingTechnique.cpp	E:/openmw\OpenSceneGraph\src\osgWrappers\serializers\osgTerrain\DisplacementMappingTechnique.cpp	DisplacementMappingTechnique	osgTerrain
# 3148	GeometryTechnique.cpp	E:/openmw\OpenSceneGraph\src\osgWrappers\serializers\osgTerrain\GeometryTechnique.cpp	GeometryTechnique	osgTerrain
# 3149	HeightFieldLayer.cpp	E:/openmw\OpenSceneGraph\src\osgWrappers\serializers\osgTerrain\HeightFieldLayer.cpp	HeightFieldLayer	osgTerrain
# 3150	ImageLayer.cpp	E:/openmw\OpenSceneGraph\src\osgWrappers\serializers\osgTerrain\ImageLayer.cpp	ImageLayer	osgTerrain
# 3151	Layer.cpp	E:/openmw\OpenSceneGraph\src\osgWrappers\serializers\osgTerrain\Layer.cpp	Layer	osgTerrain
# 3152	LibraryWrapper.cpp	E:/openmw\OpenSceneGraph\src\osgWrappers\serializers\osgTerrain\LibraryWrapper.cpp	LibraryWrapper	osgTerrain
# 3153	Locator.cpp	E:/openmw\OpenSceneGraph\src\osgWrappers\serializers\osgTerrain\Locator.cpp	Locator	osgTerrain
# 3154	ProxyLayer.cpp	E:/openmw\OpenSceneGraph\src\osgWrappers\serializers\osgTerrain\ProxyLayer.cpp	ProxyLayer	osgTerrain
# 3155	SwitchLayer.cpp	E:/openmw\OpenSceneGraph\src\osgWrappers\serializers\osgTerrain\SwitchLayer.cpp	SwitchLayer	osgTerrain
# 3156	Terrain.cpp	E:/openmw\OpenSceneGraph\src\osgWrappers\serializers\osgTerrain\Terrain.cpp	Terrain	osgTerrain
# 3157	TerrainTechnique.cpp	E:/openmw\OpenSceneGraph\src\osgWrappers\serializers\osgTerrain\TerrainTechnique.cpp	TerrainTechnique	osgTerrain
# 3158	TerrainTile.cpp	E:/openmw\OpenSceneGraph\src\osgWrappers\serializers\osgTerrain\TerrainTile.cpp	TerrainTile	osgTerrain
# 3159	FadeText.cpp	E:/openmw\OpenSceneGraph\src\osgWrappers\serializers\osgText\FadeText.cpp	FadeText	osgText
# 3160	LibraryWrapper.cpp	E:/openmw\OpenSceneGraph\src\osgWrappers\serializers\osgText\LibraryWrapper.cpp	LibraryWrapper	osgText
# 3161	Text.cpp	E:/openmw\OpenSceneGraph\src\osgWrappers\serializers\osgText\Text.cpp	Text	osgText
# 3162	Text3D.cpp	E:/openmw\OpenSceneGraph\src\osgWrappers\serializers\osgText\Text3D.cpp	Text3D	osgText
# 3163	TextBase.cpp	E:/openmw\OpenSceneGraph\src\osgWrappers\serializers\osgText\TextBase.cpp	TextBase	osgText
# 3164	AlignmentSettings.cpp	E:/openmw\OpenSceneGraph\src\osgWrappers\serializers\osgUI\AlignmentSettings.cpp	AlignmentSettings	osgUI
# 3165	ColorPalette.cpp	E:/openmw\OpenSceneGraph\src\osgWrappers\serializers\osgUI\ColorPalette.cpp	ColorPalette	osgUI
# 3166	ComboBox.cpp	E:/openmw\OpenSceneGraph\src\osgWrappers\serializers\osgUI\ComboBox.cpp	ComboBox	osgUI
# 3167	Dialog.cpp	E:/openmw\OpenSceneGraph\src\osgWrappers\serializers\osgUI\Dialog.cpp	Dialog	osgUI
# 3168	DoubleValidator.cpp	E:/openmw\OpenSceneGraph\src\osgWrappers\serializers\osgUI\DoubleValidator.cpp	DoubleValidator	osgUI
# 3169	FrameSettings.cpp	E:/openmw\OpenSceneGraph\src\osgWrappers\serializers\osgUI\FrameSettings.cpp	FrameSettings	osgUI
# 3170	IntValidator.cpp	E:/openmw\OpenSceneGraph\src\osgWrappers\serializers\osgUI\IntValidator.cpp	IntValidator	osgUI
# 3171	Item.cpp	E:/openmw\OpenSceneGraph\src\osgWrappers\serializers\osgUI\Item.cpp	Item	osgUI
# 3172	Label.cpp	E:/openmw\OpenSceneGraph\src\osgWrappers\serializers\osgUI\Label.cpp	Label	osgUI
# 3173	LineEdit.cpp	E:/openmw\OpenSceneGraph\src\osgWrappers\serializers\osgUI\LineEdit.cpp	LineEdit	osgUI
# 3174	Popup.cpp	E:/openmw\OpenSceneGraph\src\osgWrappers\serializers\osgUI\Popup.cpp	Popup	osgUI
# 3175	PushButton.cpp	E:/openmw\OpenSceneGraph\src\osgWrappers\serializers\osgUI\PushButton.cpp	PushButton	osgUI
# 3176	Tab.cpp	E:/openmw\OpenSceneGraph\src\osgWrappers\serializers\osgUI\Tab.cpp	Tab	osgUI
# 3177	TabWidget.cpp	E:/openmw\OpenSceneGraph\src\osgWrappers\serializers\osgUI\TabWidget.cpp	TabWidget	osgUI
# 3178	TextSettings.cpp	E:/openmw\OpenSceneGraph\src\osgWrappers\serializers\osgUI\TextSettings.cpp	TextSettings	osgUI
# 3179	Validator.cpp	E:/openmw\OpenSceneGraph\src\osgWrappers\serializers\osgUI\Validator.cpp	Validator	osgUI
# 3180	Widget.cpp	E:/openmw\OpenSceneGraph\src\osgWrappers\serializers\osgUI\Widget.cpp	Widget	osgUI
# 3181	CullVisitor.cpp	E:/openmw\OpenSceneGraph\src\osgWrappers\serializers\osgUtil\CullVisitor.cpp	CullVisitor	osgUtil
# 3182	UpdateVisitor.cpp	E:/openmw\OpenSceneGraph\src\osgWrappers\serializers\osgUtil\UpdateVisitor.cpp	UpdateVisitor	osgUtil
# 3183	AcrossAllScreens.cpp	E:/openmw\OpenSceneGraph\src\osgWrappers\serializers\osgViewer\AcrossAllScreens.cpp	AcrossAllScreens	osgViewer
# 3184	Config.cpp	E:/openmw\OpenSceneGraph\src\osgWrappers\serializers\osgViewer\Config.cpp	Config	osgViewer
# 3185	Keystone.cpp	E:/openmw\OpenSceneGraph\src\osgWrappers\serializers\osgViewer\Keystone.cpp	Keystone	osgViewer
# 3186	PanoramicSphericalDisplay.cpp	E:/openmw\OpenSceneGraph\src\osgWrappers\serializers\osgViewer\PanoramicSphericalDisplay.cpp	PanoramicSphericalDisplay	osgViewer
# 3187	SingleScreen.cpp	E:/openmw\OpenSceneGraph\src\osgWrappers\serializers\osgViewer\SingleScreen.cpp	SingleScreen	osgViewer
# 3188	SingleWindow.cpp	E:/openmw\OpenSceneGraph\src\osgWrappers\serializers\osgViewer\SingleWindow.cpp	SingleWindow	osgViewer
# 3189	SphericalDisplay.cpp	E:/openmw\OpenSceneGraph\src\osgWrappers\serializers\osgViewer\SphericalDisplay.cpp	SphericalDisplay	osgViewer
# 3190	WoWVxDisplay.cpp	E:/openmw\OpenSceneGraph\src\osgWrappers\serializers\osgViewer\WoWVxDisplay.cpp	WoWVxDisplay	osgViewer
# 3191	AlphaFuncProperty.cpp	E:/openmw\OpenSceneGraph\src\osgWrappers\serializers\osgVolume\AlphaFuncProperty.cpp	AlphaFuncProperty	osgVolume
# 3192	CompositeLayer.cpp	E:/openmw\OpenSceneGraph\src\osgWrappers\serializers\osgVolume\CompositeLayer.cpp	CompositeLayer	osgVolume
# 3193	CompositeProperty.cpp	E:/openmw\OpenSceneGraph\src\osgWrappers\serializers\osgVolume\CompositeProperty.cpp	CompositeProperty	osgVolume
# 3194	FixedFunctionTechnique.cpp	E:/openmw\OpenSceneGraph\src\osgWrappers\serializers\osgVolume\FixedFunctionTechnique.cpp	FixedFunctionTechnique	osgVolume
# 3195	ImageDetails.cpp	E:/openmw\OpenSceneGraph\src\osgWrappers\serializers\osgVolume\ImageDetails.cpp	ImageDetails	osgVolume
# 3196	ImageLayer.cpp	E:/openmw\OpenSceneGraph\src\osgWrappers\serializers\osgVolume\ImageLayer.cpp	ImageLayer	osgVolume
# 3197	IsoSurfaceProperty.cpp	E:/openmw\OpenSceneGraph\src\osgWrappers\serializers\osgVolume\IsoSurfaceProperty.cpp	IsoSurfaceProperty	osgVolume
# 3198	Layer.cpp	E:/openmw\OpenSceneGraph\src\osgWrappers\serializers\osgVolume\Layer.cpp	Layer	osgVolume
# 3199	LibraryWrapper.cpp	E:/openmw\OpenSceneGraph\src\osgWrappers\serializers\osgVolume\LibraryWrapper.cpp	LibraryWrapper	osgVolume
# 3200	LightingProperty.cpp	E:/openmw\OpenSceneGraph\src\osgWrappers\serializers\osgVolume\LightingProperty.cpp	LightingProperty	osgVolume
# 3201	Locator.cpp	E:/openmw\OpenSceneGraph\src\osgWrappers\serializers\osgVolume\Locator.cpp	Locator	osgVolume
# 3202	MaximumIntensityProjectionProperty.cpp	E:/openmw\OpenSceneGraph\src\osgWrappers\serializers\osgVolume\MaximumIntensityProjectionProperty.cpp	MaximumIntensityProjectionProperty	osgVolume
# 3203	MultipassTechnique.cpp	E:/openmw\OpenSceneGraph\src\osgWrappers\serializers\osgVolume\MultipassTechnique.cpp	MultipassTechnique	osgVolume
# 3204	Property.cpp	E:/openmw\OpenSceneGraph\src\osgWrappers\serializers\osgVolume\Property.cpp	Property	osgVolume
# 3205	PropertyAdjustmentCallback.cpp	E:/openmw\OpenSceneGraph\src\osgWrappers\serializers\osgVolume\PropertyAdjustmentCallback.cpp	PropertyAdjustmentCallback	osgVolume
# 3206	RayTracedTechnique.cpp	E:/openmw\OpenSceneGraph\src\osgWrappers\serializers\osgVolume\RayTracedTechnique.cpp	RayTracedTechnique	osgVolume
# 3207	SampleDensityProperty.cpp	E:/openmw\OpenSceneGraph\src\osgWrappers\serializers\osgVolume\SampleDensityProperty.cpp	SampleDensityProperty	osgVolume
# 3208	SampleRatioProperty.cpp	E:/openmw\OpenSceneGraph\src\osgWrappers\serializers\osgVolume\SampleRatioProperty.cpp	SampleRatioProperty	osgVolume
# 3209	ScalarProperty.cpp	E:/openmw\OpenSceneGraph\src\osgWrappers\serializers\osgVolume\ScalarProperty.cpp	ScalarProperty	osgVolume
# 3210	SwitchProperty.cpp	E:/openmw\OpenSceneGraph\src\osgWrappers\serializers\osgVolume\SwitchProperty.cpp	SwitchProperty	osgVolume
# 3211	TransferFunctionProperty.cpp	E:/openmw\OpenSceneGraph\src\osgWrappers\serializers\osgVolume\TransferFunctionProperty.cpp	TransferFunctionProperty	osgVolume
# 3212	TransparencyProperty.cpp	E:/openmw\OpenSceneGraph\src\osgWrappers\serializers\osgVolume\TransparencyProperty.cpp	TransparencyProperty	osgVolume
# 3213	Volume.cpp	E:/openmw\OpenSceneGraph\src\osgWrappers\serializers\osgVolume\Volume.cpp	Volume	osgVolume
# 3214	VolumeScene.cpp	E:/openmw\OpenSceneGraph\src\osgWrappers\serializers\osgVolume\VolumeScene.cpp	VolumeScene	osgVolume
# 3215	VolumeSettings.cpp	E:/openmw\OpenSceneGraph\src\osgWrappers\serializers\osgVolume\VolumeSettings.cpp	VolumeSettings	osgVolume
# 3216	VolumeTechnique.cpp	E:/openmw\OpenSceneGraph\src\osgWrappers\serializers\osgVolume\VolumeTechnique.cpp	VolumeTechnique	osgVolume
# 3217	VolumeTile.cpp	E:/openmw\OpenSceneGraph\src\osgWrappers\serializers\osgVolume\VolumeTile.cpp	VolumeTile	osgVolume
# 3218	CMakeCXXCompilerId.cpp	E:/openmw\out\build\x64-Debug\CMakeFiles\3.29.5-msvc4\CompilerIdCXX\CMakeCXXCompilerId.cpp	CMakeCXXCompilerId	CompilerIdCXX

# %%
@tool
def show_top_rows_from_db(count_rows: int, db_name: str) -> Dict[str, Any]:
    """
    Fetches the top N rows from the 'functions' table in the SQLite database and returns them as a formatted string.

    Args:
        count_rows (int): Number of rows to fetch.
        db_name (str): Path to the SQLite database.

    Returns:
        dict: Message indicating the result of the operation and the fetched data.
    """
    # Проверка существования файла базы данных
    if not os.path.exists(db_name):
        return {
            "message": f"Error: Database {db_name} does not exist.",
            "data": None
        }

    try:
        # Подключение к базе данных
        conn = sqlite3.connect(db_name)
        cursor = conn.cursor()

        # Выполнение SQL-запроса для выборки первых N строк
        cursor.execute(
            f"SELECT id, full_folder_name, full_function_name, code FROM functions LIMIT {count_rows}"
        )
        rows = cursor.fetchall()

        # Закрытие соединения с базой данных
        conn.close()

        # Если данные найдены, форматируем их построчно
        if rows:
            formatted_output = []
            for row in rows:
                id, full_folder_name, full_function_name, code = row

                # Форматируем содержимое столбца `code` как обычный текст
                if isinstance(code, str):
                    formatted_code = code.replace("\\n", "\n")  # Замена \n на реальные переносы строк
                else:
                    formatted_code = "No code available."

                # Формируем строку без Markdown
                formatted_row = (
                    f"ID: {id}\n"
                    f"Full Folder Name: {full_folder_name}\n"
                    f"Function Name: {full_function_name}\n"  # Добавляем отображение function_name
                    f"Code:\n{formatted_code}\n"
                    f"---\n"  # Разделитель между строками
                )
                formatted_output.append(formatted_row)

            # Объединяем все строки в один вывод
            message = (
                    f"Fetched top {count_rows} rows from database `{db_name}`.\n\n"
                    + "\n".join(formatted_output)
            )
            return {
                "message": message,
                "data": rows
            }
        else:
            return {
                "message": "No data found in the database.",
                "data": None
            }

    except sqlite3.Error as e:
        return {
            "message": f"Error working with the database: {e}",
            "data": None
        }

def show_db_node(state: GraphState) -> Dict[str, Any]:
    """
    Node adapter for the show_top_rows_from_db tool.
    Extracts count_rows and last_path_db from the state, calls the tool via invoke,
    and returns the updated state.

    Args:
        state (dict): Current state of the graph.

    Returns:
        dict: Updated state after fetching data from the database.
    """
    logging.info("Show DB node: Entering show_db_node function.")
    logging.info(f"Show DB node: Received state: {state}")

    # Извлекаем параметры из состояния
    count_rows = state.get("cleaned_args", None)
    db_name = state.get("last_path_db", None)

    logging.info(f"Show DB node: Extracted count_rows: {count_rows}")
    logging.info(f"Show DB node: Extracted db_name: {db_name}")

    # Проверяем, что база данных указана
    if not db_name or not os.path.exists(db_name):
        logging.error(f"Show DB node: Database {db_name} does not exist.")
        return {
            **state,
            "input": "",
            "result": f"Error: Database {db_name} does not exist."
        }

    # Проверяем, что count_rows указан и является положительным целым числом
    if not isinstance(count_rows, int) or count_rows <= 0:
        logging.error(f"Show DB node: Invalid count_rows value: {count_rows}")
        return {
            **state,
            "input": "",
            "result": "Error: Invalid count_rows value. Please provide a positive integer."
        }

    try:
        logging.info("Show DB node: Invoking show_top_rows_from_db tool.")
        tool_result = show_top_rows_from_db.invoke({"count_rows": count_rows, "db_name": db_name})
        logging.info(f"Show DB node: Tool result: {tool_result}")

        # Обновляем состояние
        updated_state = {
            **state,
            "input": "",
            "result": tool_result["message"],
            "output_data": tool_result["data"]  # Сохраняем данные для отображения
        }
        logging.info(f"Show DB node: Updated state: {updated_state}")

        return updated_state

    except Exception as e:
        logging.error(f"Show DB node: Error executing show_top_rows_from_db: {e}")
        return {
            **state,
            "input": "",
            "result": f"Error: Failed to execute show_db. Details: {e}"
        }

# %%
def get_function_name_from_db(function_id: int, db_name: str) -> str:
    """
    Retrieves the full function name from the database based on its ID.

    Args:
        function_id (int): ID of the function in the database.
        db_name (str): Path to the database.

    Returns:
        str: Full name of the function, or an empty string if not found.
    """
    if not db_name or not os.path.exists(db_name):
        logging.error(f"Database file {db_name} not found.")
        return ""

    try:
        logging.info(f"Connecting to database: {db_name}")
        conn = sqlite3.connect(db_name)
        cursor = conn.cursor()

        # Запрос для получения полного имени функции по её ID
        logging.info(f"Retrieving function with ID {function_id} from the database.")
        cursor.execute("""
        SELECT full_function_name FROM functions
        WHERE id = ?
        """, (function_id,))

        result = cursor.fetchone()
        conn.close()

        if result:
            logging.info(f"Function with ID {function_id} found: {result[0]}")
            return result[0]
        else:
            logging.warning(f"Function with ID {function_id} not found in the database.")
            return ""

    except Exception as e:
        logging.error(f"Error retrieving function name from database: {e}")
        return ""

@tool
def export_callstack_to_csv(
        vtune_file_path: str,
        function_id: int,
        db_path: str,
        row_limit: str = "100000"  # Лимит строк по умолчанию
) -> str:
    """
    Exports the callstack of a specific function from a .vtune file to a CSV file using Intel VTune.
    The function is identified by its ID in the database.

    Args:
        vtune_file_path (str): Path to the .vtune file.
        function_id (int): ID of the function in the database.
        db_path (str): Path to the database.
        row_limit (str, optional): Maximum number of rows to export. Default is "100000".

    Returns:
        str: Message indicating the result of the operation.
    """
    logging.info("Starting export_callstack_to_csv tool.")

    # Проверка входных данных
    if not vtune_file_path:
        logging.error("VTune file path is required.")
        return "Error: VTune file path is required."
    if not vtune_file_path.endswith(".vtune"):
        logging.error(f"File must have .vtune extension. Provided: {vtune_file_path}")
        return "Error: File must have .vtune extension."
    if not os.path.exists(vtune_file_path):
        logging.error(f"File {vtune_file_path} not found.")
        return f"Error: File {vtune_file_path} not found."

    if not db_path or not os.path.exists(db_path):
        logging.error(f"Database file {db_path} not found.")
        return f"Error: Database file {db_path} not found."

    # Получение полного имени функции из базы данных по её ID
    logging.info(f"Retrieving function name for ID {function_id} from database.")
    full_function_name = get_function_name_from_db(function_id, db_path)
    if not full_function_name:
        logging.error(f"Function with ID {function_id} not found in the database.")
        return f"Error: Function with ID {function_id} not found in the database."

    try:
        # Формирование имени выходного файла
        file_name = os.path.splitext(os.path.basename(vtune_file_path))[0]
        safe_function_name = full_function_name.replace("::", "_").replace(" ", "_")  # Безопасное имя функции
        output_csv = f"{file_name}_callstack_{safe_function_name}_{function_id}.csv"
        logging.info(f"Output CSV file will be created: {output_csv}")

        # Команда для экспорта callstacks
        command = (
            f'vtune -R callstacks '
            f'-r "{shlex.quote(vtune_file_path)}" '
            f'-report-output "{output_csv}" '
            f'-format csv '
            f'-csv-delimiter comma '
            f'-filter "function={full_function_name}" '
            f'-limit {row_limit}'
        )
        logging.info(f"Executing VTune command: {command}")

        # Выполнение команды
        subprocess.run(command, shell=True, check=True)

        logging.info(f"Callstack data for function '{full_function_name}' exported to {output_csv}")
        return f"Callstack data for function '{full_function_name}' exported to {output_csv}"

    except subprocess.CalledProcessError as e:
        logging.error(f"Export failed: {e}")
        return f"Export failed: {e}"

def export_callstack_node(state: GraphState) -> GraphState:
    """
    Node adapter for the export_callstack_to_csv tool.
    Extracts parameters from cleaned_args and state, calls the tool using invoke, and updates the state.

    Args:
        state (GraphState): Current state of the graph.

    Returns:
        GraphState: Updated state after exporting callstack data.
    """
    logging.info("Starting export_callstack_node.")

    # Извлекаем cleaned_args из состояния
    cleaned_args = state.get("cleaned_args", "")
    last_path_vtune = state.get("last_path_vtune", None)
    last_path_db = state.get("last_path_db", None)

    # Разбираем cleaned_args на отдельные параметры
    args_list = cleaned_args.split()
    if len(args_list) < 1:
        logging.error("Insufficient arguments for export_callstack.")
        return {
            **state,
            "result": "Error: Insufficient arguments for export_callstack.",
        }

    # Извлекаем обязательные параметры
    function_id = int(args_list[0])  # Первый параметр - function_id

    # Инициализируем необязательные параметры значениями по умолчанию
    row_limit = args_list[1] if len(args_list) > 1 else "100000"  # Лимит строк по умолчанию

    # Проверяем обязательные параметры
    if not last_path_vtune:
        logging.error("VTune file path is required (last_path_vtune).")
        return {
            **state,
            "result": "Error: VTune file path is required (last_path_vtune).",
        }
    if not last_path_db:
        logging.error("Database file path is required (last_path_db).")
        return {
            **state,
            "result": "Error: Database file path is required (last_path_db).",
        }
    if function_id is None:
        logging.error("Function ID is required.")
        return {
            **state,
            "result": "Error: Function ID is required.",
        }

    # Вызываем тул для экспорта callstack с помощью метода invoke
    try:
        logging.info(f"Invoking export_callstack_to_csv with function_id={function_id}, row_limit={row_limit}.")
        tool_result = export_callstack_to_csv.invoke(
            {
                "vtune_file_path": last_path_vtune,
                "function_id": function_id,
                "db_path": last_path_db,
                "row_limit": row_limit
            }
        )
        logging.info(f"Tool executed successfully: {tool_result}")
    except Exception as e:
        logging.error(f"Error executing export_callstack_to_csv: {e}")
        return {
            **state,
            "result": f"Error executing export_callstack_to_csv: {e}",
        }

    # Возвращаем обновленное состояние
    return {
        **state,
        "input": "",
        "result": tool_result,  # Результат работы тула
        "last_path_callstack": tool_result.split("exported to ")[-1].strip(),  # Сохраняем путь в новое поле
    }

# %%
@tool
def filter_callstack_to_csv(
        input_csv_path: str,
        call_number_limit: int,
        subcall_number_limit: int,
        output_folder: str = None
) -> str:
    """
    Filters the callstack data based on call_number_limit and subcall_number_limit.
    Saves the filtered data to a new CSV file.

    Args:
        input_csv_path (str): Path to the input CSV file.
        call_number_limit (int): Maximum number of top-level calls to include.
        subcall_number_limit (int): Maximum number of subcalls for each top-level call.
        output_folder (str, optional): Folder to save the filtered CSV file. Defaults to the folder of the input file.

    Returns:
        str: Message indicating the result of the operation and the path to the filtered file.
    """
    logging.info("Starting filter_callstack_to_csv tool.")

    # Проверка существования входного файла
    if not os.path.exists(input_csv_path):
        logging.error(f"Input file {input_csv_path} does not exist.")
        return f"Error: Input file {input_csv_path} does not exist."

    try:
        # Чтение CSV-файла
        with open(input_csv_path, "r", encoding="utf-8") as file:
            lines = file.readlines()

        # Формирование имени выходного файла
        file_name = os.path.splitext(os.path.basename(input_csv_path))[0]
        output_csv = f"filtered_{call_number_limit}_{subcall_number_limit}_{file_name}.csv"
        if output_folder:
            output_csv = os.path.join(output_folder, output_csv)
        else:
            output_csv = os.path.join(os.path.dirname(input_csv_path), output_csv)

        # Инициализация результата
        result_lines = []
        result_lines.append(lines[0].strip())  # Заголовок
        result_lines.append(lines[1].strip())
        # Разделение на блоки функций
        function_blocks = []
        current_block = []

        for line in lines[2:]:
            stripped_line = line.strip()
            if not stripped_line:
                continue  # Пропускаем пустые строки

            # Разделяем строку по запятым
            parts = stripped_line.split(",")
            if len(parts) < 3:
                continue  # Пропускаем строки без достаточного количества полей

            cpu_time = parts[2].strip()  # CPU Time находится в третьем столбце
            if cpu_time and float(cpu_time) > 0:
                # Если текущая строка имеет ненулевое время, это начало нового блока
                if current_block:
                    function_blocks.append(current_block)
                current_block = [stripped_line]
            else:
                # Добавляем строку в текущий блок
                current_block.append(stripped_line)

        # Добавляем последний блок, если он есть
        if current_block:
            function_blocks.append(current_block)

        # Логирование найденных блоков
        for i, block in enumerate(function_blocks, start=1):
            logging.debug(f"Found block #{i}:")
            logging.debug("\n".join(block))

        # Обработка блоков функций
        call_count = 0
        seen_functions = set()
        for block in function_blocks:
            if call_count >= call_number_limit:
                break  # Ограничение на количество функций

            logging.info(f"Processing block #{call_count + 1}:")
            logging.info("\n".join(block))  # Отображение содержимого блока

            # Добавляем строки из блока с учетом лимита подвызовов
            subcall_count = 0
            for subcall in block:
                if subcall_count >= subcall_number_limit:
                    break  # Ограничение на количество подвызовов

                # Разделяем строку по запятым
                parts = subcall.split(",")

                function_stack = parts[1].strip()  # Поле Function Stack
                if function_stack in seen_functions and subcall_count != 0:
                    continue  # Пропускаем повторяющуюся функцию

                # Добавляем функцию в множество и результат
                seen_functions.add(function_stack)
                result_lines.append(subcall)
                subcall_count += 1

            call_count += 1

        # Запись результата в новый CSV-файл
        with open(output_csv, "w", encoding="utf-8") as file:
            file.write("\n".join(result_lines))

        logging.info(f"Filtered data saved to {output_csv}")
        return f"Filtered callstack data saved to {output_csv}"

    except Exception as e:
        logging.error(f"Error filtering callstack data: {e}")
        return f"Error: Failed to filter callstack data. Details: {e}"

def filter_callstack_node(state: GraphState) -> GraphState:
    """
    Node adapter for the filter_callstack_to_csv tool.
    Extracts parameters from cleaned_args and state, calls the tool using invoke, and updates the state.

    Args:
        state (GraphState): Current state of the graph.

    Returns:
        GraphState: Updated state after filtering callstack data.
    """
    logging.info("Starting filter_callstack_node.")

    # Извлекаем cleaned_args из состояния
    cleaned_args = state.get("cleaned_args", "")
    last_path_callstack = state.get("last_path_callstack", None)

    # Разбираем cleaned_args на отдельные параметры
    args_list = cleaned_args.split()
    if len(args_list) < 2:
        logging.error("Insufficient arguments for filter_callstack.")
        return {
            **state,
            "result": "Error: Insufficient arguments for filter_callstack. Expected format: 'call_number_limit subcall_number_limit'.",
        }

    # Извлекаем обязательные параметры
    try:
        call_number_limit = int(args_list[0])  # Первый параметр - call_number_limit
        subcall_number_limit = int(args_list[1])  # Второй параметр - subcall_number_limit
    except ValueError:
        logging.error("Invalid arguments for filter_callstack. Both call_number_limit and subcall_number_limit must be integers.")
        return {
            **state,
            "result": "Error: Invalid arguments for filter_callstack. Both call_number_limit and subcall_number_limit must be integers.",
        }

    # Проверяем обязательные параметры
    if not last_path_callstack or not os.path.exists(last_path_callstack):
        logging.error("Callstack file path is required (last_path_callstack).")
        return {
            **state,
            "result": "Error: Callstack file path is required (last_path_callstack).",
        }

    # Вызываем тул для фильтрации стека вызовов
    try:
        logging.info(f"Invoking filter_callstack_to_csv with call_number_limit={call_number_limit}, subcall_number_limit={subcall_number_limit}.")
        tool_result = filter_callstack_to_csv.invoke(
            {
                "input_csv_path": last_path_callstack,
                "call_number_limit": call_number_limit,
                "subcall_number_limit": subcall_number_limit
            }
        )
        logging.info(f"Tool executed successfully: {tool_result}")
    except Exception as e:
        logging.error(f"Error executing filter_callstack_to_csv: {e}")
        return {
            **state,
            "result": f"Error executing filter_callstack_to_csv: {e}",
        }

    # Возвращаем обновленное состояние
    return {
        **state,
        "input": "",
        "result": tool_result,  # Результат работы тула
        "last_path_callstack": tool_result.split("saved to ")[-1].strip(),  # Сохраняем путь в новое поле
    }

# %%
@tool
def save_callstack(path_db: str, path_callstack: str) -> str:
    """
    Saves callstack dependencies to the database.
    Creates the 'callstacks' table if it does not exist and populates it with data from the callstack file.

    Args:
        path_db (str): Path to the database file.
        path_callstack (str): Path to the callstack CSV file.

    Returns:
        str: Message indicating the result of the operation.
    """
    logging.info("Starting save_callstack tool.")

    # Проверка существования файлов
    if not path_db or not os.path.exists(path_db):
        logging.error("Database file is not specified or does not exist.")
        return "Error: Database file is not specified or does not exist."

    if not path_callstack or not os.path.exists(path_callstack):
        logging.error("Callstack file is not specified or does not exist.")
        return "Error: Callstack file is not specified or does not exist."

    try:
        # Подключение к базе данных
        conn = sqlite3.connect(path_db)
        cursor = conn.cursor()

        # Создание таблицы callstacks, если она не существует
        cursor.execute("""
            CREATE TABLE IF NOT EXISTS callstacks (
                id INTEGER PRIMARY KEY AUTOINCREMENT,
                id_function INTEGER NOT NULL,
                full_func_name TEXT NOT NULL,
                FOREIGN KEY (id_function) REFERENCES functions(id)
            )
        """)
        conn.commit()

        # Чтение CSV-файла с callstack
        with open(path_callstack, "r", encoding="utf-8") as file:
            lines = file.readlines()

        # Первая строка содержит основную функцию
        header = lines[1].strip().split(",")
        main_function_name = header[0]  # Значение из столбца "Function"

        # Поиск id_function в таблице functions
        cursor.execute("SELECT id FROM functions WHERE full_function_name = ?", (main_function_name,))
        result = cursor.fetchone()
        if not result:
            logging.error(f"Function '{main_function_name}' not found in the 'functions' table.")
            return f"Error: Function '{main_function_name}' not found in the 'functions' table."

        id_function = result[0]

        # Заполнение таблицы callstacks
        for line in lines[1:]:
            stripped_line = line.strip()
            if not stripped_line:
                continue  # Пропускаем пустые строки

            parts = stripped_line.split(",")
            if len(parts) < 2:
                continue  # Пропускаем строки без достаточного количества полей

            function_stack = parts[1].strip()  # Значение из столбца "Function Stack"
            if function_stack:
                cursor.execute(
                    "INSERT INTO callstacks (id_function, full_func_name) VALUES (?, ?)",
                    (id_function, function_stack)
                )

        conn.commit()
        conn.close()

        logging.info("Callstack dependencies saved to the database.")
        return f"Callstack dependencies successfully saved to {path_db}."

    except Exception as e:
        logging.error(f"Error saving callstack dependencies: {e}")
        return f"Error: Failed to save callstack dependencies. Details: {e}"

def save_callstack_node(state: GraphState) -> GraphState:
    """
    Node adapter for the save_callstack tool.
    Extracts parameters from the state, calls the tool via invoke, and returns the updated state.

    Args:
        state (dict): Current state of the graph.

    Returns:
        dict: Updated state after saving callstack data.
    """
    logging.info("Entering save_callstack_node function.")
    logging.info(f"Received state: {state}")

    # Извлечение параметров из состояния
    path_db = state.get("last_path_db", None)
    path_callstack = state.get("last_path_callstack", None)

    # Проверка обязательных параметров
    if not path_db or not os.path.exists(path_db):
        logging.error("Database path is not specified or does not exist.")
        return {
            **state,
            "input": "",
            "result": "Error: Database path is not specified or does not exist."
        }

    if not path_callstack or not os.path.exists(path_callstack):
        logging.error("Callstack file path is not specified or does not exist.")
        return {
            **state,
            "input": "",
            "result": "Error: Callstack file path is not specified or does not exist."
        }

    try:
        # Вызов тула через invoke
        logging.info("Invoking save_callstack tool via invoke.")
        tool_result = save_callstack.invoke({"path_db": path_db, "path_callstack": path_callstack})
        logging.info(f"Tool result: {tool_result}")

        # Обновление состояния
        updated_state = {
            **state,
            "input": "",
            "result": tool_result  # Результат работы тула
        }

        return updated_state

    except Exception as e:
        logging.error(f"Error executing save_callstack tool: {e}")
        return {
            **state,
            "input": "",
            "result": f"Error executing save_callstack tool: {e}"
        }

# %%
import sqlite3

def print_callstack_table(db_name: str) -> None:
    """
    Debugging function to print the entire content of the 'callstacks' table to the console.

    Args:
        db_name (str): Path to the database file.
    """
    # Проверка существования файла базы данных
    if not db_name or not os.path.exists(db_name):
        print(f"Error: Database file {db_name} not found.")
        return

    try:
        # Подключение к базе данных
        conn = sqlite3.connect(db_name)
        cursor = conn.cursor()

        # Проверка существования таблицы callstacks
        cursor.execute("SELECT name FROM sqlite_master WHERE type='table' AND name='callstacks';")
        table_exists = cursor.fetchone()
        if not table_exists:
            print("Error: Table 'callstacks' does not exist in the database.")
            conn.close()
            return

        # Выборка всех данных из таблицы callstacks
        cursor.execute("SELECT * FROM callstacks;")
        rows = cursor.fetchall()

        # Получение заголовков столбцов
        column_names = [description[0] for description in cursor.description]

        # Вывод заголовков
        print("\t".join(column_names))

        # Вывод строк таблицы
        for row in rows:
            print("\t".join(map(str, row)))

        # Закрытие соединения
        conn.close()

    except Exception as e:
        print(f"Error printing 'callstacks' table: {e}")

print_callstack_table("E:\\AAStudy\\0_work\\Work\\Chukanov\\MyWork\\Diplom\\GPTPROF\\openmw.db")
# Out:
# id	id_function	full_func_name
# 1	5	MWRender::IntersectionVisitorWithIgnoreList::apply
# 2	5	SceneUtil::PositionAttitudeTransform::accept
# 3	5	osg::Group::traverse
# 4	5	MWRender::IntersectionVisitorWithIgnoreList::apply
# 5	5	NifOsg::MatrixTransform::accept
# 6	5	osg::Group::traverse

# %%
@tool
def prepare_callstack(callstack_file_path: str) -> str:
    """
    Prepares a new CSV file from the given callstack file.
    Removes the first row, renames the 'Function Stack' column to 'Function',
    and keeps the 'Module' and 'Source File' columns unchanged.

    Args:
        callstack_file_path (str): Path to the input callstack CSV file.

    Returns:
        str: A message indicating the result of the operation.
    """
    # Проверка существования входного файла
    if not callstack_file_path or not os.path.exists(callstack_file_path):
        return f"Error: Callstack file {callstack_file_path} does not exist."

    try:
        # Чтение CSV-файла
        df = pd.read_csv(callstack_file_path)

        # Удаление первой строки
        if len(df) > 0:
            df = df.iloc[1:]

        if len(df.columns) > 0:
            df = df.iloc[:, 1:]
        
        # Переименование столбца 'Function Stack' в 'Function'
        if "Function Stack" in df.columns:
            df.rename(columns={"Function Stack": "Function"}, inplace=True)
        else:
            return "Error: Column 'Function Stack' not found in the input file."

        # Проверка наличия необходимых столбцов
        required_columns = {"Function", "Module", "Source File"}
        if not required_columns.issubset(df.columns):
            missing_columns = required_columns - set(df.columns)
            return f"Error: Missing required columns in the input file: {missing_columns}"

        # Формирование имени нового файла
        base_name = os.path.basename(callstack_file_path)
        new_file_name = f"prepared_{base_name}"
        new_file_path = os.path.join(os.path.dirname(callstack_file_path), new_file_name)

        # Сохранение нового CSV-файла
        df.to_csv(new_file_path, index=False)

        return f"New callstack file prepared successfully: {new_file_path}"

    except Exception as e:
        return f"Error preparing callstack file: {e}"

def prepare_callstack_node(state: GraphState) -> Dict[str, Any]:
    """
    Node adapter for the prepare_callstack tool.
    Extracts callstack file path from the state, calls the tool via invoke,
    and returns the updated state.

    Args:
        state (GraphState): Current state of the graph.

    Returns:
        dict: Updated state after preparing the callstack file.
    """
    # Извлечение пути до callstack файла из состояния
    callstack_file_path = state.get("last_path_callstack")

    # Проверка существования файла
    if not callstack_file_path or not os.path.exists(callstack_file_path):
        return {
            **state,
            "result": f"Error: Callstack file {callstack_file_path} does not exist."
        }

    try:
        # Вызов тула для подготовки нового файла через invoke
        logging.info(f"Prepare callstack node: Invoking prepare_callstack for file {callstack_file_path}.")
        tool_result = prepare_callstack.invoke({"callstack_file_path": callstack_file_path})
        logging.info(f"Prepare callstack node: Tool result: {tool_result}")

        # Обновление состояния
        updated_state = {
            **state,
            "input": "",
            "result": tool_result
        }
        logging.info(f"Prepare callstack node: Updated state: {updated_state}")
        return updated_state

    except Exception as e:
        logging.error(f"Prepare callstack node: Error executing prepare_callstack: {e}")
        return {
            **state,
            "result": f"Error: Failed to execute prepare_callstack. Details: {e}"
        }

# %%
@tool
def chat_with_model(input_text: str) -> str:
    """
    Tool to interact with the MistralAI model (codestral).
    Sends user input to the model and returns the generated response.

    Args:
        input_text (str): User input text.

    Returns:
        str: Generated response from the model.
    """
    # Проверка, что входной текст не пустой
    if not input_text.strip():
        return "Please provide some input."

    try:
        # Отправка запроса в модель
        logging.info(f"Sending input to the model: {input_text}")
        response = llm.invoke([("user", f"{input_text}")])

        # Извлечение текста из ответа модели
        if hasattr(response, "content"):
            model_response = response.content
        else:
            model_response = str(response)

        logging.info(f"Model response: {model_response}")
        return model_response

    except Exception as e:
        logging.error(f"Error communicating with the model: {e}")
        return f"Error: Failed to communicate with the model. Details: {e}"


def chat_node(state: GraphState) -> GraphState:
    """
    Node adapter for the chat_with_model tool.
    Extracts user input from the state, calls the tool, and returns the updated state.

    Args:
        state (GraphState): Current state of the graph.

    Returns:
        GraphState: Updated state after processing the chat input.
    """
    logging.info("Entering chat_node function.")
    logging.info(f"Received state: {state}")

    # Извлечение входного текста из состояния
    input_text = state.get("input", "").strip()

    # Если текст пустой, возвращаем сообщение об ошибке
    if not input_text:
        return {
            **state,
            "result": "Error: Input text is empty."
        }

    try:
        # Вызов тула для обработки чата
        logging.info("Invoking chat_with_model tool.")
        tool_result = chat_with_model(input_text)
        logging.info(f"Tool result: {tool_result}")

        # Обновление состояния
        updated_state = {
            **state,
            "input": "",
            "result": tool_result
        }

        return updated_state

    except Exception as e:
        logging.error(f"Error executing chat_with_model tool: {e}")
        return {
            **state,
            "result": f"Error executing chat_with_model tool: {e}"
        }

# %%
@tool
def optimize_function_by_id(function_id: int, db_path: str) -> Dict[str, Any]:
    """
    Optimizes a function by its ID in the database using Mistral AI.
    Retrieves the function's code from the database and sends it to Mistral for optimization.

    Args:
        function_id (int): The ID of the function in the database.
        db_path (str): The path to the database.

    Returns:
        dict: A message indicating the result of the operation.
    """
    # Проверка существования базы данных
    if not db_path or not os.path.exists(db_path):
        return {
            "result": "Error: Database path is not specified or does not exist."
        }

    try:
        # Подключение к базе данных
        conn = sqlite3.connect(db_path)
        cursor = conn.cursor()

        # Получение кода функции по её ID
        cursor.execute("""
        SELECT code FROM functions
        WHERE id = ?
        """, (function_id,))
        result = cursor.fetchone()
        conn.close()

        if not result:
            return {
                "result": f"Error: Function with ID {function_id} not found in the database."
            }

        # Извлечение кода функции
        original_code = result[0]

        prompt = (
            "You are an expert C++ developer with extensive experience in code optimization. "
            "Your task is to analyze and optimize the following code while preserving its functionality. "
            "Identify performance bottlenecks and suggest appropriate time and memory optimization tools. "
            "Consider the following aspects in your optimization process: "
            "1. Algorithmic efficiency: Improve time complexity where possible. "
            "2. Memory usage: Reduce memory consumption without sacrificing performance. "
            "3. Concurrency: Utilize multi-threading or parallel processing where applicable. "
            "4. Data structures: Use appropriate data structures for better performance. "
            "5. Call stack analysis: Identify places where call stack optimization might be beneficial. "
            "6. Parallelism: Look for opportunities to introduce parallelism to improve performance. "
            "7. Time vs. memory trade-offs: Suggest optimizations that balance time and memory usage based on the context. "
            "8. Code readability: Ensure the code remains understandable and well-documented. "
            "9. Error handling: Implement robust error handling mechanisms. "
            "10. Tool suggestions: Suggest tools for analyzing parallelism and identifying places to examine the call stack. "
            "Provide a comprehensive explanation of the changes made, detailing the rationale behind each optimization. "
            "Offer recommendations for further optimization. "
            "Note: Do not suggest changing compilation flags.\n\n"
            f"Original Code:\n{original_code}"
        )

        # Отправка запроса в Mistral через invoke
        response = llm.invoke(prompt)

        # Извлечение оптимизированного кода и объяснения из ответа
        optimized_code = response.content

        # Формирование итогового сообщения
        message = (
            f"Начальный код функции (ID {function_id}):\n"
            f"```cpp\n{original_code}\n```\n\n"
            f"Оптимизированный код:\n"
            f"```cpp\n{optimized_code}\n```\n\n"
        )

        return {
            "result": message
        }

    except Exception as e:
        return {
            "result": f"Ошибка: Не удалось оптимизировать код. Подробности: {e}"
        }

def optimize_function_node(state: GraphState) -> GraphState:
    """
    Node adapter for the optimize_function_by_id tool.
    Extracts function_id from cleaned_args and db_path from the state, calls the tool, and returns the updated state.

    Args:
        state (GraphState): Current state of the graph.

    Returns:
        dict: Updated state after optimizing the function.
    """
    # Извлечение cleaned_args и db_path из состояния
    cleaned_args = state.get("cleaned_args", "")
    db_path = state.get("last_path_db")

    # Проверка существования базы данных
    if not db_path or not os.path.exists(db_path):
        return {
            **state,
            "result": f"Error: Database path {db_path} does not exist."
        }

    try:
        # Парсинг function_id из cleaned_args
        parts = cleaned_args.split()
        if len(parts) < 1:
            return {
                **state,
                "result": "Error: Missing function ID in cleaned_args."
            }

        function_id = int(parts[0])

    except ValueError:
        return {
            **state,
            "result": "Error: Invalid function ID. Function ID must be an integer."
        }

    try:
        # Вызов тула для оптимизации функции
        logging.info(f"Optimize function node: Invoking optimize_function_by_id for function_id={function_id}.")
        tool_result = optimize_function_by_id.invoke({
            "function_id": function_id,
            "db_path": db_path
        })
        logging.info(f"Optimize function node: Tool result: {tool_result}")

        # Обновление состояния
        updated_state = {
            **state,
            "input": "",
            "result": tool_result["result"]
        }
        logging.info(f"Optimize function node: Updated state: {updated_state}")
        return updated_state

    except Exception as e:
        logging.error(f"Optimize function node: Error executing optimize_function_by_id: {e}")
        return {
            **state,
            "result": f"Error: Failed to execute optimize_function_by_id. Details: {e}"
        }

# %%
@tool
def optimize_function_with_callstack(function_id: int, db_path: str) -> Dict[str, Any]:
    """
    Optimizes a function by its ID in the database using Mistral AI, taking into account its callstack.
    Retrieves the function's code and related callstack functions from the database and sends them to Mistral for optimization.

    Args:
        function_id (int): The ID of the function in the database.
        db_path (str): The path to the database.

    Returns:
        dict: A message indicating the result of the operation.
    """
    # Проверка существования базы данных
    if not db_path or not os.path.exists(db_path):
        return {
            "result": "Error: Database path is not specified or does not exist."
        }

    try:
        # Подключение к базе данных
        conn = sqlite3.connect(db_path)
        cursor = conn.cursor()

        # Получение кода основной функции по её ID
        cursor.execute("""
        SELECT code FROM functions
        WHERE id = ?
        """, (function_id,))
        main_result = cursor.fetchone()

        if not main_result:
            return {
                "result": f"Error: Function with ID {function_id} not found in the database."
            }

        # Извлечение кода основной функции
        original_code = main_result[0]

        # Получение callstack для функции
        cursor.execute("""
        SELECT full_func_name FROM callstacks
        WHERE id_function = ?
        """, (function_id,))
        callstack_results = cursor.fetchall()

        # Список имен функций из callstack
        list_func_names = [row[0] for row in callstack_results]

        # Сбор кода всех функций из callstack
        callstack_codes = []
        for func_name in list_func_names:
            cursor.execute("""
            SELECT code FROM functions
            WHERE full_function_name = ?
            """, (func_name,))
            func_result = cursor.fetchone()
            if func_result and func_result[0]:  # Если код найден
                callstack_codes.append((func_name, func_result[0]))

        conn.close()

        # Формирование промта
        prompt_parts = [
            "You are an expert C++ developer with extensive experience in code optimization. "
            "Your task is to analyze and optimize the following code while preserving its functionality. "
            "Identify performance bottlenecks and suggest appropriate time and memory optimization tools. "
            "Consider the following aspects in your optimization process: "
            "1. Algorithmic efficiency: Improve time complexity where possible. "
            "2. Memory usage: Reduce memory consumption without sacrificing performance. "
            "3. Concurrency: Utilize multi-threading or parallel processing where applicable. "
            "4. Data structures: Use appropriate data structures for better performance. "
            "5. Call stack analysis: Identify places where call stack optimization might be beneficial. "
            "6. Parallelism: Look for opportunities to introduce parallelism to improve performance. "
            "7. Time vs. memory trade-offs: Suggest optimizations that balance time and memory usage based on the context. "
            "8. Code readability: Ensure the code remains understandable and well-documented. "
            "9. Error handling: Implement robust error handling mechanisms. "
            "10. Tool suggestions: Suggest tools for analyzing parallelism and identifying places to examine the call stack. "
            "Provide a comprehensive explanation of the changes made, detailing the rationale behind each optimization. "
            "Offer recommendations for further optimization. "
            "Note: Do not suggest changing compilation flags.\n\n"
            f"Original Code:\n{original_code}\n\n"
        ]

        # Добавление кода функций из callstack
        for func_name, func_code in callstack_codes:
            prompt_parts.append(f"Callstack Function ({func_name}):\n```cpp\n{func_code}\n```\n\n")

        prompt = "".join(prompt_parts)
        logging.info(f"Check promt: {prompt}")
        # Отправка запроса в Mistral через invoke
        response = llm.invoke(prompt)

        # Извлечение оптимизированного кода и объяснения из ответа
        optimized_code = response.content

        # Формирование итогового сообщения
        message = (
            f"Initial code of the function (ID {function_id}):\n"
            f"```cpp\n{original_code}\n```\n\n"
            f"Optimized code:\n"
            f"```cpp\n{optimized_code}\n```\n\n"
        )

        return {
            "result": message
        }
        
    except Exception as e:
        return {
            "result": f"Error: Failed to optimize the code. Details: {e}"
        }

def optimize_function_with_callstack_node(state: GraphState) -> GraphState:
    """
    Node adapter for the optimize_function_with_callstack tool.
    Extracts function_id from cleaned_args and db_path from the state, calls the tool, and returns the updated state.

    Args:
        state (GraphState): Current state of the graph.

    Returns:
        dict: Updated state after optimizing the function.
    """
    # Извлечение cleaned_args и db_path из состояния
    cleaned_args = state.get("cleaned_args", "")
    db_path = state.get("last_path_db")

    # Проверка существования базы данных
    if not db_path or not os.path.exists(db_path):
        return {
            **state,
            "result": f"Error: Database path {db_path} does not exist."
        }

    try:
        # Парсинг function_id из cleaned_args
        parts = cleaned_args.split()
        if len(parts) < 1:
            return {
                **state,
                "result": "Error: Missing function ID in cleaned_args."
            }

        function_id = int(parts[0])

    except ValueError:
        return {
            **state,
            "result": "Error: Invalid function ID. Function ID must be an integer."
        }

    try:
        # Вызов тула для оптимизации функции с учетом callstack
        logging.info(f"Optimize function with callstack node: Invoking optimize_function_with_callstack for function_id={function_id}.")
        tool_result = optimize_function_with_callstack.invoke({
            "function_id": function_id,
            "db_path": db_path
        })
        logging.info(f"Optimize function with callstack node: Tool result: {tool_result}")

        # Обновление состояния
        updated_state = {
            **state,
            "input": "",
            "result": tool_result["result"]
        }
        logging.info(f"Optimize function with callstack node: Updated state: {updated_state}")
        return updated_state

    except Exception as e:
        logging.error(f"Optimize function with callstack node: Error executing optimize_function_with_callstack: {e}")
        return {
            **state,
            "result": f"Error: Failed to execute optimize_function_with_callstack. Details: {e}"
        }

# %%
def parse_command_node(state: GraphState) -> Dict[str, Any]:
    """
    Parses the user input and updates the state with parsed data.

    Args:
        state (dict): Current state of the graph.

    Returns:
        dict: Updated state with parsed data.
    """
    # Извлекаем входной запрос пользователя
    input_str = state.get("input", "").strip()

    if not input_str:
        return {
            "message": "Error: Empty input.",
            "state": state
        }

    # Разделяем команду на части
    parts = input_str.split(maxsplit=1)
    command = parts[0].lower()  # Команда (например, export, filter, filter_top)
    args = parts[1] if len(parts) > 1 else None  # Аргументы

    # Обработка команды export
    if command == "export":
        vtune_file_path = args.strip() if args else None
        return {
            **state,
            "command": "export",
            "args": args,
            "cleaned_args": vtune_file_path,
            "last_path_vtune": vtune_file_path
        }

    # Обработка команды filter
    elif command == "filter":
        module_names = [arg.strip() for arg in args.split(",") if arg.strip()] if args else []
        return {
            **state,
            "command": "filter",
            "args": args,
            "cleaned_args": module_names,
            "module_names": module_names
        }

    # Обработка команды filter_top
    elif command == "filter_top":
        top_n = args.strip() if args else None
        return {
            **state,
            "command": "filter_top",
            "args": args,
            "cleaned_args": top_n,
            "top_n": top_n
        }
    
    elif command == "save_paths":
        directory = args.strip() if args else None
        return {
            **state,
            "command": "save_paths",
            "args": args,
            "cleaned_args": directory,
            "directory": directory
        }
    
    elif command == "process_functions":
        return {
            **state,
            "command": "process_functions",
            "args": args,
            "cleaned_args": args
        }
    
    elif command == "show_db":
        try:
            count_rows = int(args.strip()) if args else None
            return {
                **state,
                "command": "show_db",
                "args": args,
                "cleaned_args": count_rows
            }
        except ValueError:
            return {
                **state,
                "command": "show_db",
                "args": args,
                "cleaned_args": None
            }

    elif command == "export_callstack":
        cleaned_args = args.strip() if args else ""
        return {
            **state,
            "command": "export_callstack",
            "args": args,
            "cleaned_args": cleaned_args
        }
    
    elif command == "filter_callstack":
        cleaned_args = args.strip() if args else ""
        return {
            **state,
            "command": "filter_callstack",
            "args": args,
            "cleaned_args": cleaned_args
        }
    
    elif command == "save_callstack":
        cleaned_args = args.strip() if args else ""
        return {
            **state,
            "command": "save_callstack",
            "args": args,
            "cleaned_args": cleaned_args
        }
    
    elif command == "prepare_callstack":
        cleaned_args = args.strip() if args else ""
        return {
            **state,
            "command": "prepare_callstack",
            "args": args,
            "cleaned_args": cleaned_args
        }
    
    elif command == "optimize_function_by_id":
        cleaned_args = args.strip() if args else ""
        return {
            **state,
            "command": "optimize_function_by_id",
            "args": args,
            "cleaned_args": cleaned_args
        }

    elif command == "optimize_function_with_callstack":
        cleaned_args = args.strip() if args else ""
        return {
            **state,
            "command": "optimize_function_with_callstack",
            "args": args,
            "cleaned_args": cleaned_args
        }
    
    # Если команда не распознана
    else:
        return {
            **state,
            "command": "chat",
            "args": None,
            "cleaned_args": None
        }

# %%
# Создаем граф
workflow = StateGraph(GraphState)

# Добавляем узлы
workflow.add_node("parse", parse_command_node)
workflow.add_node("export", export_vtune_node)
workflow.add_node("filter", filter_by_module_node)
workflow.add_node("filter_top", filter_top_node)
workflow.add_node("save_paths", save_paths_node)
workflow.add_node("process_functions", process_functions_node)
workflow.add_node("show_db", show_db_node)
workflow.add_node("export_callstack", export_callstack_node)
workflow.add_node("filter_callstack", filter_callstack_node)
workflow.add_node("save_callstack", save_callstack_node)
workflow.add_node("prepare_callstack", prepare_callstack_node)
workflow.add_node("chat", chat_node)
workflow.add_node("optimize_function_by_id", optimize_function_node)
workflow.add_node("optimize_function_with_callstack", optimize_function_with_callstack_node)

# Добавляем рёбра
workflow.add_edge(START, "parse")

# Большой условный переход после парсера
def conditional_edge(state: GraphState) -> str:
    """
    Determines the next node based on the parsed command.

    Args:
        state (GraphState): Current state of the graph.

    Returns:
        str: Name of the next node.
    """
    logging.info(f"Conditional edge: state in input '{state}'")
    command = state.get("command", "")
    logging.info(f"Conditional edge: Received command '{command}' from state.")

    if command == "export":
        return "export"
    elif command == "filter":
        return "filter"
    elif command == "filter_top":
        return "filter_top"
    elif command == "save_paths":
        return "save_paths"
    elif command == "process_functions":
        return "process_functions"
    elif command == "show_db":
        return "show_db"
    elif command == "export_callstack":
        return "export_callstack"
    elif command == "filter_callstack":
        return "filter_callstack"
    elif command == "save_callstack":
        return "save_callstack"
    elif command == "prepare_callstack":
        return "prepare_callstack"
    elif command == "optimize_function_by_id":
        return "optimize_function_by_id"
    elif command == "optimize_function_with_callstack":
        return "optimize_function_with_callstack"
    elif command == "chat":
        return "chat"
    else:
        logging.warning(f"Conditional edge: Unknown command '{command}'. Moving to END.")
        return END

workflow.add_conditional_edges("parse", conditional_edge)

# Добавляем рёбра к концу
workflow.add_edge("export", END)
workflow.add_edge("filter", END)
workflow.add_edge("filter_top", END)
workflow.add_edge("save_paths", END)
workflow.add_edge("process_functions", END)
workflow.add_edge("show_db", END)
workflow.add_edge("export_callstack", END)
workflow.add_edge("filter_callstack", END)
workflow.add_edge("save_callstack", END)
workflow.add_edge("prepare_callstack", END)
workflow.add_edge("optimize_function_by_id", END)
workflow.add_edge("optimize_function_with_callstack", END)
workflow.add_edge("chat", END)

# Компилируем граф
compiled_graph = workflow.compile()

# Gradio интерфейс
import logging

# Настройка логирования
logging.basicConfig(
    level=logging.DEBUG,
    format="%(asctime)s - %(levelname)s - %(message)s",  # Формат логов
    handlers=[
        logging.StreamHandler(),  # Вывод в консоль
        logging.FileHandler("codestral.log")  # Сохранение в файл
    ]
)

# Gradio интерфейс
def ask_codestral(user_input: str, session_state: dict = None):
    """
    Processes user input and updates the state using the compiled graph.
    Handles the 'exit' command to terminate the Gradio interface.

    Args:
        user_input (str): User input string.
        session_state (dict, optional): Current state of the session.

    Returns:
        tuple: Result message and updated state.
    """
    # Логируем входные данные
    logging.info(f"Received user input: {user_input}")
    if session_state:
        if session_state["input"] == "":
            session_state["input"] = user_input
    logging.info(f"Session state before processing: {session_state}")
    
    
    # Инициализируем состояние
    # state = session_state or {
    #     "input": user_input,
    #     "result": "",
    #     "last_path_vtune": None,
    #     "last_path_csv": None,
    #     "last_path_db": "openmw.db",
    #     "last_path_callstack": None,
    #     "module_names": [],
    #     "command": "",
    #     "args": "",
    #     "cleaned_args": "",
    #     "top_n": ""
    # }

    state = session_state or {
        "input": user_input,
        "result": "",
        "last_path_vtune": "E:/openmw/OMW_2/r002hs/r002hs.vtune",
        "last_path_csv": "top_10_filtered_r002hs.csv",
        "last_path_db": "openmw.db",
        "last_path_callstack": "r002hs_callstack_MWRender_IntersectionVisitorWithIgnoreList_skipTransform_5.csv",
        "module_names": [],
        "command": "",
        "args": "",
        "cleaned_args": "",
        "top_n": ""
    }

    try:
        # Проверяем, является ли команда "exit"
        if user_input.strip().lower() == "exit":
            logging.info("Exit command received. Terminating the session.")
            if gradio_interface_instance is not None:
                gradio_interface_instance.close()
            os._exit(0)

        # Логируем вызов графа
        logging.info("Invoking the graph with the current state.")
        result_state = compiled_graph.invoke(state)

        # Логируем результат выполнения графа
        logging.info(f"Graph execution completed. Result state: {result_state}")
        return result_state["result"], result_state  # Перезапись глобального состояния

    except Exception as e:
        # Логируем ошибку
        logging.error(f"An error occurred during graph execution: {e}")
        return f"Error: {str(e)}", state

def gradio_interface(user_input: str, session_state: dict = None):
    return ask_codestral(user_input, session_state)

def launch_gradio():
    global gradio_interface_instance

    if gradio_interface_instance is not None:
        gradio_interface_instance.close()

    with gr.Blocks() as interface:
        # Две колонки: левая для ввода команд, правая для вывода результатов
        with gr.Row():
            # Левая колонка: Command
            with gr.Column(scale=1):
                gr.Markdown("### Command Input")
                cmd_input = gr.Textbox(
                    label="Enter Command",
                    placeholder="",
                    interactive=True,
                    lines=5
                )
                submit_btn = gr.Button("Submit", variant="primary")

            # Правая колонка: Output
            with gr.Column(scale=2):
                gr.Markdown("### Output")
                output = gr.Textbox(
                    label="Output",
                    value="Ready to process commands.",
                    lines=25,
                    interactive=False
                )

        # Состояние сессии
        session_state = gr.State()

        def process_command(cmd: str, state: dict):
            """
            Processes the user command and updates the Gradio interface.

            Args:
                cmd (str): User input command.
                state (dict): Current session state.

            Returns:
                tuple: Response message and updated state.
            """
            try:
                # Выполнение команды через граф
                response, new_state = gradio_interface(cmd, state)
                return response, new_state

            except Exception as e:
                # Обработка ошибок
                error_message = f"Error processing command: {e}"
                return error_message, state

        # Обработка нажатия кнопки и Enter в текстовом поле
        submit_btn.click(
            process_command,
            inputs=[cmd_input, session_state],
            outputs=[output, session_state]
        )
        cmd_input.submit(
            process_command,
            inputs=[cmd_input, session_state],
            outputs=[output, session_state]
        )

        # Инструкции для пользователя
        with gr.Row():
            gr.Markdown("""
            ### Available commands:
            - `export path/to/file.vtune` - Export VTune data to CSV (e.g. `export results.vtune`)
            - `filter module1,module2,...` - Filter data by specified modules
            - `show_db count_rows` - Show top N rows from the database
            - `exit` - Terminate the session
            """)

    gradio_interface_instance = interface

    # Настройки запуска
    interface.launch(
        server_port=7860,
        inbrowser=False,
        share=False,
        show_error=True
    )

# %%
# Запускаем интерфейс
launch_gradio()
# Out:
# 2025-04-23 22:58:35,939 - DEBUG - Starting new HTTPS connection (1): huggingface.co:443
# 2025-04-23 22:58:36,081 - DEBUG - connect_tcp.started host='api.gradio.app' port=443 local_address=None timeout=3 socket_options=None
# 2025-04-23 22:58:36,212 - DEBUG - https://huggingface.co:443 "HEAD /api/telemetry/gradio/initiated HTTP/1.1" 200 0
# 2025-04-23 22:58:36,407 - DEBUG - connect_tcp.complete return_value=<httpcore._backends.sync.SyncStream object at 0x0000023F83A4AF10>
# 2025-04-23 22:58:36,408 - DEBUG - start_tls.started ssl_context=<ssl.SSLContext object at 0x0000023F83159E20> server_hostname='api.gradio.app' timeout=3
# 2025-04-23 22:58:36,679 - DEBUG - Using selector: SelectSelector
# 2025-04-23 22:58:36,745 - DEBUG - start_tls.complete return_value=<httpcore._backends.sync.SyncStream object at 0x0000023F836D9290>
# 2025-04-23 22:58:36,747 - DEBUG - send_request_headers.started request=<Request [b'GET']>
# 2025-04-23 22:58:36,750 - DEBUG - send_request_headers.complete
# 2025-04-23 22:58:36,750 - DEBUG - send_request_body.started request=<Request [b'GET']>
# 2025-04-23 22:58:36,751 - DEBUG - send_request_body.complete
# 2025-04-23 22:58:36,753 - DEBUG - receive_response_headers.started request=<Request [b'GET']>
# 2025-04-23 22:58:36,916 - DEBUG - receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Date', b'Wed, 23 Apr 2025 19:58:36 GMT'), (b'Content-Type', b'application/json'), (b'Content-Length', b'21'), (b'Connection', b'keep-alive'), (b'Server', b'nginx/1.18.0'), (b'Access-Control-Allow-Origin', b'*')])
# 2025-04-23 22:58:36,916 - INFO - HTTP Request: GET https://api.gradio.app/pkg-version "HTTP/1.1 200 OK"
# 2025-04-23 22:58:36,919 - DEBUG - receive_response_body.started request=<Request [b'GET']>
# 2025-04-23 22:58:36,920 - DEBUG - receive_response_body.complete
# 2025-04-23 22:58:36,921 - DEBUG - response_closed.started
# 2025-04-23 22:58:36,922 - DEBUG - response_closed.complete
# 2025-04-23 22:58:36,922 - DEBUG - close.started
# 2025-04-23 22:58:36,925 - DEBUG - close.complete
# * Running on local URL:  http://127.0.0.1:7860
# 2025-04-23 22:58:37,215 - DEBUG - connect_tcp.started host='127.0.0.1' port=7860 local_address=None timeout=None socket_options=None
# 2025-04-23 22:58:37,217 - DEBUG - connect_tcp.complete return_value=<httpcore._backends.sync.SyncStream object at 0x0000023F836A0450>
# 2025-04-23 22:58:37,219 - DEBUG - send_request_headers.started request=<Request [b'GET']>
# 2025-04-23 22:58:37,276 - DEBUG - send_request_headers.complete
# 2025-04-23 22:58:37,279 - DEBUG - send_request_body.started request=<Request [b'GET']>
# 2025-04-23 22:58:37,281 - DEBUG - send_request_body.complete
# 2025-04-23 22:58:37,282 - DEBUG - receive_response_headers.started request=<Request [b'GET']>
# 2025-04-23 22:58:37,283 - DEBUG - receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'date', b'Wed, 23 Apr 2025 19:58:36 GMT'), (b'server', b'uvicorn'), (b'content-length', b'4'), (b'content-type', b'application/json')])
# 2025-04-23 22:58:37,284 - INFO - HTTP Request: GET http://127.0.0.1:7860/gradio_api/startup-events "HTTP/1.1 200 OK"
# 2025-04-23 22:58:37,286 - DEBUG - receive_response_body.started request=<Request [b'GET']>
# 2025-04-23 22:58:37,287 - DEBUG - receive_response_body.complete
# 2025-04-23 22:58:37,288 - DEBUG - response_closed.started
# 2025-04-23 22:58:37,289 - DEBUG - response_closed.complete
# 2025-04-23 22:58:37,290 - DEBUG - close.started
# 2025-04-23 22:58:37,291 - DEBUG - close.complete
# 2025-04-23 22:58:37,293 - DEBUG - connect_tcp.started host='127.0.0.1' port=7860 local_address=None timeout=3 socket_options=None
# 2025-04-23 22:58:37,335 - DEBUG - connect_tcp.complete return_value=<httpcore._backends.sync.SyncStream object at 0x0000023F83671C90>
# 2025-04-23 22:58:37,336 - DEBUG - send_request_headers.started request=<Request [b'HEAD']>
# 2025-04-23 22:58:37,337 - DEBUG - send_request_headers.complete
# 2025-04-23 22:58:37,339 - DEBUG - send_request_body.started request=<Request [b'HEAD']>
# 2025-04-23 22:58:37,340 - DEBUG - send_request_body.complete
# 2025-04-23 22:58:37,341 - DEBUG - receive_response_headers.started request=<Request [b'HEAD']>
# 2025-04-23 22:58:37,549 - DEBUG - receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'date', b'Wed, 23 Apr 2025 19:58:36 GMT'), (b'server', b'uvicorn'), (b'content-length', b'11072'), (b'content-type', b'text/html; charset=utf-8')])
# 2025-04-23 22:58:37,550 - INFO - HTTP Request: HEAD http://127.0.0.1:7860/ "HTTP/1.1 200 OK"
# 2025-04-23 22:58:37,552 - DEBUG - receive_response_body.started request=<Request [b'HEAD']>
# 2025-04-23 22:58:37,553 - DEBUG - receive_response_body.complete
# 2025-04-23 22:58:37,554 - DEBUG - response_closed.started
# 2025-04-23 22:58:37,554 - DEBUG - response_closed.complete
# 2025-04-23 22:58:37,555 - DEBUG - close.started
# 2025-04-23 22:58:37,556 - DEBUG - close.complete
# To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7860/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# 2025-04-23 22:58:37,567 - DEBUG - Starting new HTTPS connection (1): huggingface.co:443
